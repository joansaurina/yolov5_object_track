# %% [markdown]
# # **Pipeline for object detection and tracking in 3D:**

# %% [markdown]
# ### **Required packages:**

# %%
#!pip install -r requirements.txt 
#!pip install setuptools==69.2.0
import torch
import numpy as np
import cv2
from matplotlib import pyplot as plt
import os
from itertools import zip_longest

from pathlib import Path
from models.common import DetectMultiBackend
from utils.general import (Profile, cv2, non_max_suppression, scale_boxes, xyxy2xywh)
from utils.augmentations import letterbox
from utils.torch_utils import select_device, smart_inference_mode
from sort import Sort

# %% [markdown]
# ### **1. Definition of Objects and Functions**

# %% [markdown]
# ##### 2D Object detection : YOLOV5

# %%
# DEFINE PARAMETERS:

weights="weights/X-704.pt"
source_1="data/view1"
source_2="data/view2"
device="cpu"
project="runs"
name="exp"
save_path = "outputs"

image_size=(512, 512)
conf_thres=0.25
max_det=20
line_thickness=2
iou_thres=0.45

save_txt=True
save_csv=False
nosave=False
hide_labels=False 
hide_conf=True

# DEFINE PARAMETERS FOR SORT:
sort_max_age = 5 
sort_min_hits = 2
sort_iou_thresh = 0.2
track_color_id = 0

# %%
class ObjectDetector():
    
    def __init__(self, device, weights, source_1, source_2, image_size, save_path):
        self.device = select_device(device)
        self.model = DetectMultiBackend(weights, self.device)
        self.model.names = dict(list(self.model.names.items())[:2] + list(self.model.names.items())[4:])
        self.stride, self.names, self.pt = self.model.stride, self.model.names, self.model.pt
        self.imgsz = image_size
        self.model.warmup(imgsz=(1 , 3, *self.imgsz))
        self.dt = Profile(device=self.device)
        self.source_1 = Path(source_1)
        self.source_2 = Path(source_2)
        self.files_1 = [f for f in self.source_1.glob('*') if f.suffix.lower() in ['.jpg', '.jpeg', '.png']]
        self.files_2 = [f for f in self.source_2.glob('*') if f.suffix.lower() in ['.jpg', '.jpeg', '.png']]
        
        self.save_path = save_path
        if not os.path.exists(self.save_path):
            os.makedirs(self.save_path)
        self.track_color_id = 0
        self.sort_tracker = Sort(max_age=sort_max_age, min_hits=sort_min_hits, iou_threshold=sort_iou_thresh) 
        
    def __iter__(self):
        for file_1, file_2 in zip_longest(self.files_1, self.files_2, fillvalue=None):
            img_1 = cv2.imread(str(file_1))
            img_2 = cv2.imread(str(file_2))
            yield (img_1, img_2)
    
    def draw_boxes(self, img, bbox, identities=None, categories=None, names=None, offset=(0, 0)):
        for i, box in enumerate(bbox):
            x1, y1, x2, y2 = [int(i) for i in box]
            x1 += offset[0]
            x2 += offset[0]
            y1 += offset[1]
            y2 += offset[1]
            id = int(identities[i]) if identities is not None else 0
            data = (int((box[0]+box[2])/2),(int((box[1]+box[3])/2)))
            label = str(id)

            color = self.compute_color_for_labels(id)
            (w, h), _ = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.6, 1)
            cv2.rectangle(img, (x1, y1), (x2, y2),color, 2)
            cv2.rectangle(img, (x1, y1 - 20), (x1 + w, y1), (255,191,0), -1)
            cv2.putText(img, label, (x1, y1 - 5),cv2.FONT_HERSHEY_SIMPLEX, 0.6, 
            [255, 255, 255], 1)
            cv2.circle(img, data, 3, color,-1)

        return img
    
    @smart_inference_mode()
    def detect_object_2D(self, im, frame_num, save_images):
        with self.dt:
            image_original = im
            im = letterbox(im, self.imgsz, stride=self.stride, auto=True)[0]
            im = im.transpose((2, 0, 1))[::-1]
            im = np.ascontiguousarray(im)
            im = torch.from_numpy(im).to(self.device)
            im = im.float().unsqueeze(0)
            im /= 255
                        
            pred = self.model(im)
            pred = non_max_suppression(pred)
            
            for det in pred:
                gn = torch.tensor(image_original.shape)[[1, 0, 1, 0]] #Normalization
                det[:, :4] = scale_boxes(im.shape[2:], det[:, :4], image_original.shape).round() # Rescale to original size
                
                dets_to_sort = np.empty((0, 6))
                for *xyxy, conf, cls in reversed(det):
                    if cls not in [0, 1, 4]:
                        continue
                    
                    c = int(cls)
                    coords = ((xyxy2xywh(torch.tensor(xyxy).view(1, 4)) / gn).view(-1).tolist())  # Normalized xywh
                    #{conf:.2f}", *coords
                    # Agregar detección a dets_to_sort para clases 0 y 1
                    x1, y1, x2, y2 = [int(coord) for coord in xyxy]
                    dets_to_sort = np.vstack((dets_to_sort, np.array([x1, y1, x2, y2, conf, c])))
                            
                # Run SORT:
                tracked_dets = self.sort_tracker.update(dets_to_sort)
                tracks = self.sort_tracker.getTrackers()
                
                #OUTPUT:
                for track in tracks:
                    if save_images:
                        color = self.compute_color_for_labels(self.track_color_id)
                        [cv2.line(image_original, (int(track.centroidarr[i][0]),int(track.centroidarr[i][1])), 
                                (int(track.centroidarr[i+1][0]),int(track.centroidarr[i+1][1])),
                                color, thickness=3) for i,_ in  enumerate(track.centroidarr) 
                                if i < len(track.centroidarr)-1 ] 
                        self.track_color_id += 1
                    line = (f"{frame_num} {track.id} {self.names[track.detclass]} {0 if track.time_since_update < 5 else 1} {'-'} {'-'}")
                    print(line)
                    
                if len(tracked_dets)>0:
                    bbox_xyxy = tracked_dets[:,:4]
                    identities = tracked_dets[:, 8]
                    categories = tracked_dets[:, 4]
                    self.draw_boxes(image_original, bbox_xyxy, identities, categories, self.names)
            
            cv2.imwrite(str(self.save_path + f"/{frame_num}.png"), image_original)

    def compute_color_for_labels(self, label, palette = (2 ** 11 - 1, 2 ** 15 - 1, 2 ** 20 - 1)):
        color = [int(int(p * (label ** 2 - label + 1)) % 255) for p in palette]
        return tuple(color)
    
    def create_video(self, images_dir, output_video_path, fps=30):
        image_files = sorted([f for f in os.listdir(images_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))])

        if not image_files:
            raise ValueError("No se encontraron imágenes en el directorio especificado.")

        # Leer la primera imagen para obtener el tamaño del video
        first_image_path = os.path.join(images_dir, image_files[0])
        first_image = cv2.imread(first_image_path)
        height, width, _ = first_image.shape

        # Definir el códec y el objeto VideoWriter
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec para archivos .mp4
        video_writer = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

        # Escribir cada imagen en el archivo de video
        for image_file in image_files:
            image_path = os.path.join(images_dir, image_file)
            frame = cv2.imread(image_path)
            video_writer.write(frame)

        # Liberar el VideoWriter
        video_writer.release()
        print(f"Video creado exitosamente: {output_video_path}")

# %%
detector = ObjectDetector(device, weights, source_1, source_2, image_size, save_path)
# Out:
# YOLOv5  v7.0-383-g1435a8ee Python-3.10.5 torch-2.5.1+cpu CPU
#
# Fusing layers...
# Model summary: 484 layers, 88417530 parameters, 0 gradients

# %% [markdown]
# ##### Z ESTIMATION:

# %%
def calculate_distance_to_object(left_center, right_center, im_left, im_right, focal_length = 707.0493, baseline = 0.06):

    # Calculate disparity (horizontal pixel difference between the left and right image)
    disparity = abs(left_center[0] - right_center[0])
    
    if disparity == 0:
        return float('inf')
    
    Z = (focal_length * baseline) / disparity
    
    return Z

# %%
for i, images in enumerate(detector):
    detector.detect_object_2D(images[0], frame_num=i, save_images=False)
    #detector.detect_object_2D(images[1], save_path=output, frame_num=i)
# Out:
# 0 486 pedestrian 0 - -
# 0 487 pedestrian 0 - -
# 0 488 pedestrian 0 - -
# 0 489 pedestrian 0 - -
# 0 490 pedestrian 0 - -
# 1 486 pedestrian 0 - -
# 1 487 pedestrian 0 - -
# 1 488 pedestrian 0 - -
# 1 489 pedestrian 0 - -
# 1 490 pedestrian 0 - -
# 1 491 vehicle 0 - -
# 2 486 pedestrian 0 - -
# 2 487 pedestrian 0 - -
# 2 488 pedestrian 0 - -
# 2 489 pedestrian 0 - -
# 2 490 pedestrian 0 - -
# 2 491 vehicle 0 - -
# 2 492 pedestrian 0 - -
# 2 493 pedestrian 0 - -
# 2 494 cyclist 0 - -
# 2 495 pedestrian 0 - -
# 3 486 pedestrian 0 - -
# 3 487 pedestrian 0 - -
# 3 488 pedestrian 0 - -
# 3 489 pedestrian 0 - -
# 3 490 pedestrian 0 - -
# 3 491 vehicle 0 - -
# 3 492 pedestrian 0 - -
# 3 493 pedestrian 0 - -
# 3 494 cyclist 0 - -
# 3 495 pedestrian 0 - -
# 3 496 pedestrian 0 - -
# 4 486 pedestrian 0 - -
# 4 487 pedestrian 0 - -
# 4 488 pedestrian 0 - -
# 4 489 pedestrian 0 - -
# 4 490 pedestrian 0 - -
# 4 491 vehicle 0 - -
# 4 492 pedestrian 0 - -
# 4 493 pedestrian 0 - -
# 4 494 cyclist 0 - -
# 4 495 pedestrian 0 - -
# 4 496 pedestrian 0 - -
# 5 486 pedestrian 0 - -
# 5 487 pedestrian 0 - -
# 5 488 pedestrian 1 - -
# 5 489 pedestrian 0 - -
# 5 490 pedestrian 1 - -
# 5 491 vehicle 0 - -
# 5 492 pedestrian 0 - -
# 5 493 pedestrian 0 - -
# 5 494 cyclist 0 - -
# 5 495 pedestrian 0 - -
# 5 496 pedestrian 0 - -
# 5 497 cyclist 0 - -
# 6 486 pedestrian 0 - -
# 6 487 pedestrian 0 - -
# 6 489 pedestrian 0 - -
# 6 491 vehicle 0 - -
# 6 492 pedestrian 0 - -
# 6 493 pedestrian 0 - -
# 6 494 cyclist 0 - -
# 6 495 pedestrian 0 - -
# 6 496 pedestrian 0 - -
# 6 497 cyclist 0 - -
# 7 486 pedestrian 0 - -
# 7 487 pedestrian 0 - -
# 7 489 pedestrian 0 - -
# 7 491 vehicle 0 - -
# 7 492 pedestrian 1 - -
# 7 493 pedestrian 0 - -
# 7 494 cyclist 1 - -
# 7 495 pedestrian 0 - -
# 7 496 pedestrian 0 - -
# 7 497 cyclist 0 - -
# 7 498 cyclist 0 - -
# 7 499 vehicle 0 - -
# 7 500 cyclist 0 - -
# 8 486 pedestrian 0 - -
# 8 487 pedestrian 0 - -
# 8 489 pedestrian 0 - -
# 8 491 vehicle 0 - -
# 8 493 pedestrian 0 - -
# 8 495 pedestrian 0 - -
# 8 496 pedestrian 0 - -
# 8 497 cyclist 0 - -
# 8 498 cyclist 0 - -
# 8 499 vehicle 0 - -
# 8 500 cyclist 0 - -
# 9 486 pedestrian 0 - -
# 9 487 pedestrian 0 - -
# 9 489 pedestrian 0 - -
# 9 491 vehicle 0 - -
# 9 493 pedestrian 0 - -
# 9 495 pedestrian 0 - -
# 9 496 pedestrian 0 - -
# 9 497 cyclist 0 - -
# 9 498 cyclist 0 - -
# 9 499 vehicle 0 - -
# 9 500 cyclist 0 - -
# 9 501 vehicle 0 - -
# 10 486 pedestrian 0 - -
# 10 487 pedestrian 0 - -
# 10 489 pedestrian 0 - -
# 10 491 vehicle 0 - -
# 10 493 pedestrian 0 - -
# 10 495 pedestrian 0 - -
# 10 496 pedestrian 0 - -
# 10 497 cyclist 0 - -
# 10 498 cyclist 0 - -
# 10 499 vehicle 0 - -
# 10 500 cyclist 0 - -
# 10 501 cyclist 0 - -
# 11 486 pedestrian 0 - -
# 11 487 pedestrian 0 - -
# 11 489 pedestrian 0 - -
# 11 491 vehicle 1 - -
# 11 493 pedestrian 0 - -
# 11 495 pedestrian 0 - -
# 11 496 pedestrian 0 - -
# 11 497 cyclist 0 - -
# 11 498 cyclist 0 - -
# 11 499 vehicle 0 - -
# 11 500 cyclist 0 - -
# 11 501 cyclist 0 - -
# 12 486 pedestrian 0 - -
# 12 487 pedestrian 0 - -
# 12 489 pedestrian 0 - -
# 12 493 pedestrian 0 - -
# 12 495 pedestrian 0 - -
# 12 496 pedestrian 0 - -
# 12 497 cyclist 1 - -
# 12 498 pedestrian 0 - -
# 12 499 vehicle 1 - -
# 12 500 cyclist 0 - -
# 12 501 cyclist 0 - -
# 12 502 vehicle 0 - -
# 12 503 pedestrian 0 - -
# 13 486 pedestrian 0 - -
# 13 487 pedestrian 0 - -
# 13 489 pedestrian 0 - -
# 13 493 pedestrian 0 - -
# 13 495 pedestrian 0 - -
# 13 496 vehicle 0 - -
# 13 498 pedestrian 0 - -
# 13 500 cyclist 0 - -
# 13 501 cyclist 0 - -
# 13 502 vehicle 0 - -
# 13 503 pedestrian 0 - -
# 13 504 pedestrian 0 - -
# 14 486 pedestrian 0 - -
# 14 487 pedestrian 0 - -
# 14 489 pedestrian 0 - -
# 14 493 pedestrian 0 - -
# 14 495 pedestrian 0 - -
# 14 496 vehicle 0 - -
# 14 498 pedestrian 0 - -
# 14 500 pedestrian 0 - -
# 14 501 cyclist 0 - -
# 14 502 vehicle 0 - -
# 14 503 pedestrian 0 - -
# 14 504 pedestrian 0 - -
# 14 505 cyclist 0 - -
# 15 486 pedestrian 0 - -
# 15 487 pedestrian 0 - -
# 15 489 pedestrian 0 - -
# 15 493 pedestrian 0 - -
# 15 495 pedestrian 0 - -
# 15 496 pedestrian 0 - -
# 15 498 pedestrian 0 - -
# 15 500 pedestrian 0 - -
# 15 501 cyclist 0 - -
# 15 502 vehicle 0 - -
# 15 503 pedestrian 0 - -
# 15 504 pedestrian 0 - -
# 15 505 cyclist 0 - -
# 15 506 pedestrian 0 - -
# 15 507 pedestrian 0 - -
# 15 508 pedestrian 0 - -
# 15 509 pedestrian 0 - -
# 15 510 vehicle 0 - -
# 15 511 pedestrian 0 - -
# 15 512 pedestrian 0 - -
# 15 513 pedestrian 0 - -
# 16 486 pedestrian 0 - -
# 16 487 pedestrian 0 - -
# 16 489 pedestrian 0 - -
# 16 493 pedestrian 0 - -
# 16 495 pedestrian 0 - -
# 16 496 vehicle 0 - -
# 16 498 pedestrian 0 - -
# 16 500 pedestrian 0 - -
# 16 501 cyclist 0 - -
# 16 502 vehicle 0 - -
# 16 503 pedestrian 0 - -
# 16 504 pedestrian 0 - -
# 16 505 cyclist 0 - -
# 16 506 pedestrian 0 - -
# 16 507 pedestrian 0 - -
# 16 508 pedestrian 0 - -
# 16 509 pedestrian 0 - -
# 16 510 vehicle 0 - -
# 16 511 pedestrian 0 - -
# 16 512 pedestrian 0 - -
# 16 513 pedestrian 0 - -
# 16 514 pedestrian 0 - -
# 16 515 pedestrian 0 - -
# 16 516 pedestrian 0 - -
# 16 517 pedestrian 0 - -
# 16 518 pedestrian 0 - -
# 17 486 pedestrian 0 - -
# 17 487 pedestrian 0 - -
# 17 489 pedestrian 0 - -
# 17 493 pedestrian 0 - -
# 17 495 pedestrian 0 - -
# 17 496 vehicle 0 - -
# 17 498 pedestrian 0 - -
# 17 500 pedestrian 0 - -
# 17 501 cyclist 0 - -
# 17 502 vehicle 0 - -
# 17 503 pedestrian 0 - -
# 17 504 pedestrian 0 - -
# 17 505 cyclist 0 - -
# 17 506 pedestrian 0 - -
# 17 507 pedestrian 0 - -
# 17 508 pedestrian 0 - -
# 17 509 pedestrian 0 - -
# 17 510 vehicle 0 - -
# 17 511 pedestrian 0 - -
# 17 512 pedestrian 0 - -
# 17 513 pedestrian 0 - -
# 17 514 pedestrian 0 - -
# 17 515 pedestrian 0 - -
# 17 516 pedestrian 0 - -
# 17 517 pedestrian 0 - -
# 17 518 pedestrian 0 - -
# 17 519 pedestrian 0 - -
# 18 486 pedestrian 0 - -
# 18 487 pedestrian 0 - -
# 18 489 pedestrian 0 - -
# 18 493 pedestrian 0 - -
# 18 495 pedestrian 0 - -
# 18 496 vehicle 0 - -
# 18 498 pedestrian 1 - -
# 18 500 pedestrian 0 - -
# 18 501 cyclist 0 - -
# 18 502 vehicle 1 - -
# 18 503 pedestrian 0 - -
# 18 504 pedestrian 0 - -
# 18 505 cyclist 0 - -
# 18 506 pedestrian 0 - -
# 18 507 pedestrian 0 - -
# 18 508 pedestrian 0 - -
# 18 509 pedestrian 0 - -
# 18 510 vehicle 0 - -
# 18 511 pedestrian 0 - -
# 18 512 pedestrian 0 - -
# 18 513 pedestrian 0 - -
# 18 514 pedestrian 0 - -
# 18 515 pedestrian 0 - -
# 18 516 pedestrian 0 - -
# 18 517 pedestrian 0 - -
# 18 518 pedestrian 0 - -
# 18 519 pedestrian 0 - -
# 18 520 pedestrian 0 - -
# 19 486 pedestrian 0 - -
# 19 487 pedestrian 0 - -
# 19 489 pedestrian 1 - -
# 19 493 pedestrian 0 - -
# 19 495 pedestrian 0 - -
# 19 496 vehicle 0 - -
# 19 500 pedestrian 0 - -
# 19 501 cyclist 0 - -
# 19 503 pedestrian 0 - -
# 19 504 pedestrian 1 - -
# 19 505 cyclist 1 - -
# 19 506 pedestrian 0 - -
# 19 507 pedestrian 0 - -
# 19 508 pedestrian 0 - -
# 19 509 pedestrian 0 - -
# 19 510 vehicle 0 - -
# 19 511 pedestrian 0 - -
# 19 512 pedestrian 0 - -
# 19 513 pedestrian 0 - -
# 19 514 pedestrian 0 - -
# 19 515 pedestrian 0 - -
# 19 516 pedestrian 0 - -
# 19 517 pedestrian 0 - -
# 19 518 pedestrian 0 - -
# 19 519 pedestrian 0 - -
# 19 520 pedestrian 0 - -
# 19 521 pedestrian 0 - -
# 20 486 pedestrian 0 - -
# 20 487 pedestrian 0 - -
# 20 489 pedestrian 0 - -
# 20 493 pedestrian 0 - -
# 20 495 pedestrian 0 - -
# 20 496 vehicle 0 - -
# 20 500 pedestrian 0 - -
# 20 501 cyclist 0 - -
# 20 503 pedestrian 0 - -
# 20 506 pedestrian 0 - -
# 20 507 pedestrian 1 - -
# 20 508 pedestrian 0 - -
# 20 509 pedestrian 0 - -
# 20 510 vehicle 1 - -
# 20 511 pedestrian 1 - -
# 20 512 pedestrian 1 - -
# 20 513 pedestrian 0 - -
# 20 514 pedestrian 0 - -
# 20 515 pedestrian 0 - -
# 20 516 pedestrian 0 - -
# 20 517 pedestrian 0 - -
# 20 518 pedestrian 0 - -
# 20 519 pedestrian 0 - -
# 20 520 pedestrian 0 - -
# 20 521 pedestrian 0 - -
# 21 486 pedestrian 0 - -
# 21 487 pedestrian 0 - -
# 21 489 pedestrian 0 - -
# 21 493 pedestrian 0 - -
# 21 495 pedestrian 0 - -
# 21 496 vehicle 0 - -
# 21 500 pedestrian 0 - -
# 21 501 cyclist 0 - -
# 21 503 pedestrian 0 - -
# 21 506 pedestrian 0 - -
# 21 508 pedestrian 0 - -
# 21 509 pedestrian 0 - -
# 21 510 pedestrian 0 - -
# 21 513 pedestrian 0 - -
# 21 514 pedestrian 1 - -
# 21 515 pedestrian 1 - -
# 21 516 pedestrian 0 - -
# 21 517 pedestrian 0 - -
# 21 518 pedestrian 0 - -
# 21 519 pedestrian 0 - -
# 21 520 pedestrian 0 - -
# 21 521 pedestrian 0 - -
# 22 486 pedestrian 0 - -
# 22 487 pedestrian 0 - -
# 22 489 pedestrian 0 - -
# 22 493 pedestrian 0 - -
# 22 495 pedestrian 0 - -
# 22 496 vehicle 0 - -
# 22 500 pedestrian 1 - -
# 22 501 cyclist 0 - -
# 22 503 pedestrian 0 - -
# 22 506 pedestrian 0 - -
# 22 508 pedestrian 0 - -
# 22 509 pedestrian 1 - -
# 22 510 pedestrian 0 - -
# 22 513 vehicle 0 - -
# 22 516 pedestrian 0 - -
# 22 517 pedestrian 0 - -
# 22 518 pedestrian 0 - -
# 22 519 pedestrian 1 - -
# 22 520 pedestrian 0 - -
# 22 521 pedestrian 0 - -
# 22 522 pedestrian 0 - -
# 23 486 pedestrian 0 - -
# 23 487 pedestrian 0 - -
# 23 489 pedestrian 0 - -
# 23 493 pedestrian 0 - -
# 23 495 pedestrian 0 - -
# 23 496 vehicle 0 - -
# 23 501 vehicle 0 - -
# 23 503 pedestrian 0 - -
# 23 506 pedestrian 0 - -
# 23 508 pedestrian 0 - -
# 23 509 pedestrian 0 - -
# 23 510 pedestrian 0 - -
# 23 513 pedestrian 0 - -
# 23 516 pedestrian 0 - -
# 23 517 pedestrian 0 - -
# 23 518 pedestrian 0 - -
# 23 520 pedestrian 1 - -
# 23 521 cyclist 0 - -
# 23 522 pedestrian 0 - -
# 23 523 pedestrian 0 - -
# 23 524 pedestrian 0 - -
# 24 486 pedestrian 0 - -
# 24 487 pedestrian 0 - -
# 24 489 pedestrian 0 - -
# 24 493 pedestrian 0 - -
# 24 495 pedestrian 0 - -
# 24 496 vehicle 0 - -
# 24 501 vehicle 0 - -
# 24 503 pedestrian 0 - -
# 24 506 pedestrian 0 - -
# 24 508 pedestrian 0 - -
# 24 509 pedestrian 0 - -
# 24 510 pedestrian 0 - -
# 24 513 pedestrian 0 - -
# 24 516 pedestrian 0 - -
# 24 517 pedestrian 0 - -
# 24 518 pedestrian 0 - -
# 24 521 pedestrian 0 - -
# 24 522 pedestrian 0 - -
# 24 523 pedestrian 0 - -
# 24 524 pedestrian 0 - -
# 24 525 pedestrian 0 - -
# 25 486 pedestrian 0 - -
# 25 487 pedestrian 0 - -
# 25 489 pedestrian 0 - -
# 25 493 pedestrian 0 - -
# 25 495 pedestrian 0 - -
# 25 496 vehicle 0 - -
# 25 501 vehicle 0 - -
# 25 503 pedestrian 0 - -
# 25 506 pedestrian 0 - -
# 25 508 pedestrian 1 - -
# 25 509 pedestrian 0 - -
# 25 510 pedestrian 0 - -
# 25 513 pedestrian 0 - -
# 25 516 pedestrian 0 - -
# 25 517 pedestrian 0 - -
# 25 518 pedestrian 0 - -
# 25 521 pedestrian 0 - -
# 25 522 pedestrian 0 - -
# 25 523 pedestrian 0 - -
# 25 524 pedestrian 0 - -
# 25 525 pedestrian 0 - -
# 25 526 pedestrian 0 - -
# 26 486 pedestrian 0 - -
# 26 487 pedestrian 0 - -
# 26 489 pedestrian 0 - -
# 26 493 pedestrian 0 - -
# 26 495 pedestrian 0 - -
# 26 496 vehicle 0 - -
# 26 501 pedestrian 0 - -
# 26 503 pedestrian 0 - -
# 26 506 pedestrian 0 - -
# 26 509 pedestrian 0 - -
# 26 510 pedestrian 1 - -
# 26 513 pedestrian 0 - -
# 26 516 pedestrian 0 - -
# 26 517 pedestrian 0 - -
# 26 518 pedestrian 0 - -
# 26 521 pedestrian 0 - -
# 26 522 pedestrian 0 - -
# 26 523 pedestrian 0 - -
# 26 524 pedestrian 0 - -
# 26 525 pedestrian 0 - -
# 26 526 pedestrian 0 - -
# 26 527 pedestrian 0 - -
# 26 528 pedestrian 0 - -
# 27 486 pedestrian 0 - -
# 27 487 pedestrian 0 - -
# 27 489 pedestrian 0 - -
# 27 493 pedestrian 0 - -
# 27 495 pedestrian 0 - -
# 27 496 vehicle 0 - -
# 27 501 pedestrian 0 - -
# 27 503 pedestrian 0 - -
# 27 506 pedestrian 0 - -
# 27 509 pedestrian 0 - -
# 27 513 pedestrian 0 - -
# 27 516 pedestrian 0 - -
# 27 517 pedestrian 0 - -
# 27 518 pedestrian 0 - -
# 27 521 pedestrian 0 - -
# 27 522 pedestrian 0 - -
# 27 523 pedestrian 0 - -
# 27 524 pedestrian 0 - -
# 27 525 pedestrian 0 - -
# 27 526 pedestrian 0 - -
# 27 527 pedestrian 0 - -
# 27 528 pedestrian 0 - -
# 27 529 pedestrian 0 - -
# 28 486 pedestrian 0 - -
# 28 487 pedestrian 0 - -
# 28 489 pedestrian 0 - -
# 28 493 pedestrian 0 - -
# 28 495 pedestrian 0 - -
# 28 496 vehicle 0 - -
# 28 501 pedestrian 0 - -
# 28 503 pedestrian 0 - -
# 28 506 pedestrian 0 - -
# 28 509 pedestrian 1 - -
# 28 513 pedestrian 0 - -
# 28 516 pedestrian 0 - -
# 28 517 pedestrian 0 - -
# 28 518 pedestrian 0 - -
# 28 521 pedestrian 0 - -
# 28 522 pedestrian 0 - -
# 28 523 pedestrian 1 - -
# 28 524 pedestrian 1 - -
# 28 525 pedestrian 0 - -
# 28 526 pedestrian 0 - -
# 28 527 pedestrian 0 - -
# 28 528 pedestrian 0 - -
# 28 529 pedestrian 0 - -
# 29 486 pedestrian 0 - -
# 29 487 pedestrian 0 - -
# 29 489 pedestrian 0 - -
# 29 493 pedestrian 0 - -
# 29 495 pedestrian 0 - -
# 29 496 vehicle 0 - -
# 29 501 pedestrian 0 - -
# 29 503 pedestrian 0 - -
# 29 506 pedestrian 0 - -
# 29 513 pedestrian 0 - -
# 29 516 pedestrian 0 - -
# 29 517 pedestrian 0 - -
# 29 518 pedestrian 0 - -
# 29 521 pedestrian 0 - -
# 29 522 pedestrian 0 - -
# 29 525 pedestrian 0 - -
# 29 526 pedestrian 0 - -
# 29 527 pedestrian 0 - -
# 29 528 pedestrian 0 - -
# 29 529 pedestrian 0 - -
# 30 486 pedestrian 0 - -
# 30 487 pedestrian 0 - -
# 30 489 pedestrian 0 - -
# 30 493 pedestrian 0 - -
# 30 495 pedestrian 0 - -
# 30 496 vehicle 1 - -
# 30 501 pedestrian 0 - -
# 30 503 pedestrian 0 - -
# 30 506 pedestrian 0 - -
# 30 513 pedestrian 0 - -
# 30 516 pedestrian 0 - -
# 30 517 pedestrian 0 - -
# 30 518 pedestrian 0 - -
# 30 521 pedestrian 0 - -
# 30 522 pedestrian 0 - -
# 30 525 pedestrian 0 - -
# 30 526 pedestrian 0 - -
# 30 527 pedestrian 0 - -
# 30 528 pedestrian 0 - -
# 30 529 pedestrian 0 - -
# 30 530 pedestrian 0 - -
# 31 486 pedestrian 0 - -
# 31 487 pedestrian 0 - -
# 31 489 pedestrian 0 - -
# 31 493 pedestrian 0 - -
# 31 495 pedestrian 0 - -
# 31 501 pedestrian 1 - -
# 31 503 pedestrian 0 - -
# 31 506 cyclist 0 - -
# 31 513 pedestrian 0 - -
# 31 516 pedestrian 0 - -
# 31 517 pedestrian 0 - -
# 31 518 pedestrian 0 - -
# 31 521 pedestrian 0 - -
# 31 522 pedestrian 0 - -
# 31 525 pedestrian 0 - -
# 31 526 pedestrian 0 - -
# 31 527 pedestrian 0 - -
# 31 528 pedestrian 0 - -
# 31 529 pedestrian 0 - -
# 31 530 pedestrian 0 - -
# 32 486 pedestrian 0 - -
# 32 487 pedestrian 0 - -
# 32 489 pedestrian 0 - -
# 32 493 pedestrian 0 - -
# 32 495 pedestrian 0 - -
# 32 503 pedestrian 0 - -
# 32 506 pedestrian 0 - -
# 32 513 pedestrian 0 - -
# 32 516 pedestrian 0 - -
# 32 517 pedestrian 0 - -
# 32 518 pedestrian 0 - -
# 32 521 pedestrian 1 - -
# 32 522 pedestrian 0 - -
# 32 525 pedestrian 0 - -
# 32 526 pedestrian 1 - -
# 32 527 pedestrian 0 - -
# 32 528 pedestrian 1 - -
# 32 529 pedestrian 0 - -
# 32 530 pedestrian 0 - -
# 33 486 pedestrian 0 - -
# 33 487 pedestrian 0 - -
# 33 489 pedestrian 0 - -
# 33 493 pedestrian 0 - -
# 33 495 pedestrian 0 - -
# 33 503 pedestrian 0 - -
# 33 506 pedestrian 0 - -
# 33 513 pedestrian 0 - -
# 33 516 pedestrian 0 - -
# 33 517 pedestrian 0 - -
# 33 518 pedestrian 0 - -
# 33 522 pedestrian 0 - -
# 33 525 pedestrian 0 - -
# 33 527 pedestrian 0 - -
# 33 529 pedestrian 0 - -
# 33 530 pedestrian 0 - -
# 33 531 cyclist 0 - -
# 34 486 pedestrian 0 - -
# 34 487 pedestrian 0 - -
# 34 489 pedestrian 0 - -
# 34 493 pedestrian 0 - -
# 34 495 pedestrian 0 - -
# 34 503 pedestrian 0 - -
# 34 506 pedestrian 0 - -
# 34 513 pedestrian 0 - -
# 34 516 pedestrian 1 - -
# 34 517 pedestrian 0 - -
# 34 518 pedestrian 0 - -
# 34 522 pedestrian 0 - -
# 34 525 pedestrian 0 - -
# 34 527 pedestrian 0 - -
# 34 529 pedestrian 0 - -
# 34 530 pedestrian 0 - -
# 34 531 cyclist 0 - -
# 35 486 pedestrian 0 - -
# 35 487 pedestrian 0 - -
# 35 489 pedestrian 0 - -
# 35 493 pedestrian 0 - -
# 35 495 pedestrian 0 - -
# 35 503 pedestrian 0 - -
# 35 506 pedestrian 0 - -
# 35 513 pedestrian 0 - -
# 35 517 pedestrian 0 - -
# 35 518 pedestrian 0 - -
# 35 522 pedestrian 0 - -
# 35 525 pedestrian 0 - -
# 35 527 pedestrian 0 - -
# 35 529 pedestrian 0 - -
# 35 530 pedestrian 0 - -
# 35 531 cyclist 0 - -
# 35 532 cyclist 0 - -
# 35 533 pedestrian 0 - -
# 36 486 pedestrian 0 - -
# 36 487 pedestrian 0 - -
# 36 489 pedestrian 0 - -
# 36 493 pedestrian 0 - -
# 36 495 pedestrian 0 - -
# 36 503 pedestrian 0 - -
# 36 506 pedestrian 0 - -
# 36 513 pedestrian 0 - -
# 36 517 pedestrian 0 - -
# 36 518 pedestrian 0 - -
# 36 522 pedestrian 0 - -
# 36 525 pedestrian 0 - -
# 36 527 pedestrian 0 - -
# 36 529 pedestrian 0 - -
# 36 530 pedestrian 0 - -
# 36 531 cyclist 0 - -
# 36 532 cyclist 0 - -
# 36 533 pedestrian 0 - -
# 36 534 cyclist 0 - -
# 36 535 pedestrian 0 - -
# 37 486 pedestrian 0 - -
# 37 487 pedestrian 0 - -
# 37 489 pedestrian 0 - -
# 37 493 pedestrian 0 - -
# 37 495 pedestrian 0 - -
# 37 503 pedestrian 0 - -
# 37 506 pedestrian 0 - -
# 37 513 pedestrian 0 - -
# 37 517 pedestrian 0 - -
# 37 518 pedestrian 0 - -
# 37 522 pedestrian 0 - -
# 37 525 pedestrian 0 - -
# 37 527 pedestrian 0 - -
# 37 529 pedestrian 0 - -
# 37 530 pedestrian 1 - -
# 37 531 cyclist 0 - -
# 37 532 cyclist 0 - -
# 37 533 pedestrian 0 - -
# 37 534 cyclist 0 - -
# 37 535 pedestrian 0 - -
# 37 536 cyclist 0 - -
# 38 486 pedestrian 0 - -
# 38 487 pedestrian 0 - -
# 38 489 pedestrian 0 - -
# 38 493 pedestrian 0 - -
# 38 495 pedestrian 0 - -
# 38 503 pedestrian 0 - -
# 38 506 pedestrian 0 - -
# 38 513 pedestrian 0 - -
# 38 517 pedestrian 0 - -
# 38 518 pedestrian 0 - -
# 38 522 pedestrian 0 - -
# 38 525 pedestrian 0 - -
# 38 527 pedestrian 1 - -
# 38 529 pedestrian 0 - -
# 38 531 cyclist 0 - -
# 38 532 cyclist 0 - -
# 38 533 pedestrian 0 - -
# 38 534 cyclist 0 - -
# 38 535 cyclist 0 - -
# 38 536 pedestrian 0 - -
# 39 486 pedestrian 0 - -
# 39 487 pedestrian 0 - -
# 39 489 pedestrian 0 - -
# 39 493 pedestrian 0 - -
# 39 495 pedestrian 0 - -
# 39 503 pedestrian 0 - -
# 39 506 pedestrian 0 - -
# 39 513 pedestrian 0 - -
# 39 517 pedestrian 0 - -
# 39 518 pedestrian 0 - -
# 39 522 pedestrian 0 - -
# 39 525 pedestrian 1 - -
# 39 527 pedestrian 0 - -
# 39 529 pedestrian 0 - -
# 39 531 cyclist 0 - -
# 39 532 cyclist 0 - -
# 39 533 pedestrian 0 - -
# 39 534 cyclist 0 - -
# 39 535 cyclist 0 - -
# 39 536 pedestrian 0 - -
# 39 537 pedestrian 0 - -
# 39 538 pedestrian 0 - -
# 39 539 cyclist 0 - -
# 40 486 pedestrian 0 - -
# 40 487 pedestrian 0 - -
# 40 489 pedestrian 0 - -
# 40 493 pedestrian 0 - -
# 40 495 pedestrian 0 - -
# 40 503 pedestrian 0 - -
# 40 506 pedestrian 0 - -
# 40 513 pedestrian 0 - -
# 40 517 pedestrian 0 - -
# 40 518 pedestrian 0 - -
# 40 522 pedestrian 1 - -
# 40 527 pedestrian 0 - -
# 40 529 pedestrian 0 - -
# 40 531 cyclist 0 - -
# 40 532 cyclist 0 - -
# 40 533 pedestrian 0 - -
# 40 534 cyclist 0 - -
# 40 535 cyclist 0 - -
# 40 536 pedestrian 0 - -
# 40 537 pedestrian 0 - -
# 40 538 pedestrian 0 - -
# 40 539 cyclist 0 - -
# 40 540 vehicle 0 - -
# 40 541 pedestrian 0 - -
# 41 486 pedestrian 0 - -
# 41 487 pedestrian 0 - -
# 41 489 pedestrian 1 - -
# 41 493 pedestrian 0 - -
# 41 495 pedestrian 0 - -
# 41 503 pedestrian 0 - -
# 41 506 pedestrian 0 - -
# 41 513 pedestrian 0 - -
# 41 517 pedestrian 0 - -
# 41 518 pedestrian 0 - -
# 41 527 pedestrian 0 - -
# 41 529 pedestrian 0 - -
# 41 531 cyclist 0 - -
# 41 532 cyclist 0 - -
# 41 533 pedestrian 0 - -
# 41 534 cyclist 0 - -
# 41 535 pedestrian 0 - -
# 41 536 cyclist 0 - -
# 41 537 pedestrian 0 - -
# 41 538 pedestrian 0 - -
# 41 539 cyclist 0 - -
# 41 540 cyclist 0 - -
# 41 541 pedestrian 0 - -
# 42 486 pedestrian 0 - -
# 42 487 pedestrian 0 - -
# 42 489 pedestrian 0 - -
# 42 493 pedestrian 0 - -
# 42 495 pedestrian 0 - -
# 42 503 pedestrian 0 - -
# 42 506 pedestrian 0 - -
# 42 513 pedestrian 0 - -
# 42 517 pedestrian 0 - -
# 42 518 pedestrian 0 - -
# 42 527 pedestrian 0 - -
# 42 529 pedestrian 0 - -
# 42 531 cyclist 0 - -
# 42 532 cyclist 0 - -
# 42 533 pedestrian 0 - -
# 42 534 cyclist 1 - -
# 42 535 cyclist 0 - -
# 42 536 pedestrian 0 - -
# 42 537 pedestrian 0 - -
# 42 538 pedestrian 0 - -
# 42 539 cyclist 0 - -
# 42 540 cyclist 0 - -
# 42 541 pedestrian 0 - -
# 42 542 cyclist 0 - -
# 42 543 cyclist 0 - -
# 42 544 pedestrian 0 - -
# 42 545 pedestrian 0 - -
# 43 486 pedestrian 0 - -
# 43 487 pedestrian 0 - -
# 43 489 pedestrian 0 - -
# 43 493 pedestrian 0 - -
# 43 495 pedestrian 0 - -
# 43 503 pedestrian 0 - -
# 43 506 pedestrian 0 - -
# 43 513 pedestrian 0 - -
# 43 517 pedestrian 0 - -
# 43 518 pedestrian 0 - -
# 43 527 pedestrian 0 - -
# 43 529 pedestrian 1 - -
# 43 531 cyclist 0 - -
# 43 532 cyclist 0 - -
# 43 533 pedestrian 0 - -
# 43 535 pedestrian 0 - -
# 43 536 cyclist 0 - -
# 43 537 pedestrian 0 - -
# 43 538 pedestrian 0 - -
# 43 539 cyclist 0 - -
# 43 540 cyclist 0 - -
# 43 541 pedestrian 0 - -
# 43 542 cyclist 0 - -
# 43 543 cyclist 0 - -
# 43 544 pedestrian 0 - -
# 43 545 pedestrian 0 - -
# 44 486 pedestrian 0 - -
# 44 487 pedestrian 0 - -
# 44 489 pedestrian 0 - -
# 44 493 pedestrian 0 - -
# 44 495 pedestrian 0 - -
# 44 503 pedestrian 0 - -
# 44 506 pedestrian 0 - -
# 44 513 pedestrian 0 - -
# 44 517 pedestrian 0 - -
# 44 518 pedestrian 0 - -
# 44 527 pedestrian 1 - -
# 44 531 cyclist 0 - -
# 44 532 cyclist 0 - -
# 44 533 pedestrian 0 - -
# 44 535 pedestrian 0 - -
# 44 536 cyclist 0 - -
# 44 537 pedestrian 0 - -
# 44 538 pedestrian 0 - -
# 44 539 cyclist 0 - -
# 44 540 cyclist 0 - -
# 44 541 pedestrian 0 - -
# 44 542 cyclist 0 - -
# 44 543 cyclist 0 - -
# 44 544 pedestrian 0 - -
# 44 545 pedestrian 0 - -
# 44 546 pedestrian 0 - -
# 44 547 pedestrian 0 - -
# 45 486 pedestrian 0 - -
# 45 487 pedestrian 0 - -
# 45 489 pedestrian 0 - -
# 45 493 pedestrian 0 - -
# 45 495 pedestrian 0 - -
# 45 503 pedestrian 0 - -
# 45 506 pedestrian 0 - -
# 45 513 pedestrian 0 - -
# 45 517 pedestrian 0 - -
# 45 518 pedestrian 0 - -
# 45 531 cyclist 0 - -
# 45 532 cyclist 0 - -
# 45 533 pedestrian 0 - -
# 45 535 pedestrian 0 - -
# 45 536 cyclist 0 - -
# 45 537 pedestrian 0 - -
# 45 538 pedestrian 1 - -
# 45 539 cyclist 1 - -
# 45 540 cyclist 0 - -
# 45 541 pedestrian 0 - -
# 45 542 cyclist 0 - -
# 45 543 cyclist 0 - -
# 45 544 pedestrian 0 - -
# 45 545 pedestrian 0 - -
# 45 546 pedestrian 0 - -
# 45 547 pedestrian 0 - -
# 45 548 pedestrian 0 - -
# 46 486 pedestrian 0 - -
# 46 487 pedestrian 0 - -
# 46 489 pedestrian 0 - -
# 46 493 pedestrian 0 - -
# 46 495 pedestrian 1 - -
# 46 503 pedestrian 0 - -
# 46 506 pedestrian 0 - -
# 46 513 pedestrian 0 - -
# 46 517 pedestrian 0 - -
# 46 518 pedestrian 0 - -
# 46 531 cyclist 0 - -
# 46 532 cyclist 0 - -
# 46 533 pedestrian 0 - -
# 46 535 pedestrian 0 - -
# 46 536 cyclist 0 - -
# 46 537 pedestrian 0 - -
# 46 540 cyclist 0 - -
# 46 541 pedestrian 1 - -
# 46 542 cyclist 0 - -
# 46 543 cyclist 0 - -
# 46 544 pedestrian 0 - -
# 46 545 pedestrian 0 - -
# 46 546 pedestrian 0 - -
# 46 547 pedestrian 0 - -
# 46 548 pedestrian 0 - -
# 46 549 pedestrian 0 - -
# 47 486 pedestrian 0 - -
# 47 487 pedestrian 0 - -
# 47 489 pedestrian 0 - -
# 47 493 pedestrian 0 - -
# 47 503 pedestrian 0 - -
# 47 506 pedestrian 0 - -
# 47 513 pedestrian 0 - -
# 47 517 pedestrian 0 - -
# 47 518 pedestrian 0 - -
# 47 531 cyclist 1 - -
# 47 532 cyclist 0 - -
# 47 533 pedestrian 0 - -
# 47 535 pedestrian 0 - -
# 47 536 cyclist 0 - -
# 47 537 pedestrian 0 - -
# 47 540 cyclist 0 - -
# 47 542 cyclist 0 - -
# 47 543 cyclist 0 - -
# 47 544 pedestrian 0 - -
# 47 545 pedestrian 0 - -
# 47 546 pedestrian 0 - -
# 47 547 pedestrian 0 - -
# 47 548 pedestrian 0 - -
# 47 549 pedestrian 0 - -
# 47 550 pedestrian 0 - -
# 48 486 pedestrian 1 - -
# 48 487 pedestrian 0 - -
# 48 489 pedestrian 0 - -
# 48 493 pedestrian 0 - -
# 48 503 pedestrian 0 - -
# 48 506 pedestrian 0 - -
# 48 513 pedestrian 0 - -
# 48 517 pedestrian 1 - -
# 48 518 pedestrian 0 - -
# 48 532 cyclist 0 - -
# 48 533 pedestrian 1 - -
# 48 535 pedestrian 0 - -
# 48 536 pedestrian 0 - -
# 48 537 pedestrian 0 - -
# 48 540 cyclist 0 - -
# 48 542 cyclist 0 - -
# 48 543 cyclist 0 - -
# 48 544 pedestrian 0 - -
# 48 545 pedestrian 0 - -
# 48 546 pedestrian 0 - -
# 48 547 pedestrian 0 - -
# 48 548 pedestrian 0 - -
# 48 549 pedestrian 0 - -
# 48 550 pedestrian 0 - -
# 48 551 pedestrian 0 - -
# 48 552 pedestrian 0 - -
# 49 487 pedestrian 0 - -
# 49 489 pedestrian 0 - -
# 49 493 pedestrian 0 - -
# 49 503 pedestrian 0 - -
# 49 506 pedestrian 0 - -
# 49 513 pedestrian 0 - -
# 49 518 pedestrian 0 - -
# 49 532 cyclist 0 - -
# 49 535 pedestrian 0 - -
# 49 536 pedestrian 0 - -
# 49 537 pedestrian 0 - -
# 49 540 cyclist 0 - -
# 49 542 cyclist 0 - -
# 49 543 cyclist 0 - -
# 49 544 pedestrian 0 - -
# 49 545 pedestrian 0 - -
# 49 546 pedestrian 0 - -
# 49 547 pedestrian 0 - -
# 49 548 pedestrian 0 - -
# 49 549 pedestrian 0 - -
# 49 550 pedestrian 0 - -
# 49 551 pedestrian 0 - -
# 49 552 pedestrian 0 - -
# 50 487 pedestrian 0 - -
# 50 489 pedestrian 0 - -
# 50 493 pedestrian 0 - -
# 50 503 pedestrian 0 - -
# 50 506 pedestrian 0 - -
# 50 513 pedestrian 0 - -
# 50 518 cyclist 0 - -
# 50 532 cyclist 0 - -
# 50 535 pedestrian 0 - -
# 50 536 cyclist 0 - -
# 50 537 pedestrian 0 - -
# 50 540 pedestrian 0 - -
# 50 542 cyclist 0 - -
# 50 543 cyclist 0 - -
# 50 544 pedestrian 0 - -
# 50 545 pedestrian 0 - -
# 50 546 pedestrian 0 - -
# 50 547 pedestrian 0 - -
# 50 548 pedestrian 0 - -
# 50 549 pedestrian 0 - -
# 50 550 pedestrian 0 - -
# 50 551 pedestrian 0 - -
# 50 552 pedestrian 0 - -
# 50 553 pedestrian 0 - -
# 50 554 pedestrian 0 - -
# 51 487 pedestrian 0 - -
# 51 489 pedestrian 1 - -
# 51 493 pedestrian 0 - -
# 51 503 pedestrian 0 - -
# 51 506 pedestrian 0 - -
# 51 513 pedestrian 0 - -
# 51 518 cyclist 0 - -
# 51 532 cyclist 0 - -
# 51 535 pedestrian 0 - -
# 51 536 cyclist 0 - -
# 51 537 pedestrian 0 - -
# 51 540 vehicle 0 - -
# 51 542 cyclist 0 - -
# 51 543 cyclist 0 - -
# 51 544 pedestrian 0 - -
# 51 545 pedestrian 1 - -
# 51 546 pedestrian 0 - -
# 51 547 pedestrian 0 - -
# 51 548 pedestrian 0 - -
# 51 549 pedestrian 0 - -
# 51 550 pedestrian 0 - -
# 51 551 pedestrian 0 - -
# 51 552 pedestrian 0 - -
# 51 553 pedestrian 0 - -
# 51 554 pedestrian 0 - -
# 52 487 pedestrian 0 - -
# 52 493 pedestrian 0 - -
# 52 503 pedestrian 0 - -
# 52 506 pedestrian 0 - -
# 52 513 pedestrian 0 - -
# 52 518 pedestrian 0 - -
# 52 532 cyclist 0 - -
# 52 535 cyclist 0 - -
# 52 536 pedestrian 0 - -
# 52 537 pedestrian 0 - -
# 52 540 cyclist 0 - -
# 52 542 cyclist 0 - -
# 52 543 cyclist 0 - -
# 52 544 pedestrian 0 - -
# 52 546 pedestrian 0 - -
# 52 547 pedestrian 0 - -
# 52 548 pedestrian 0 - -
# 52 549 pedestrian 0 - -
# 52 550 pedestrian 1 - -
# 52 551 pedestrian 0 - -
# 52 552 pedestrian 0 - -
# 52 553 pedestrian 0 - -
# 52 554 pedestrian 0 - -
# 52 555 vehicle 0 - -
# 53 487 pedestrian 0 - -
# 53 493 pedestrian 0 - -
# 53 503 pedestrian 0 - -
# 53 506 pedestrian 0 - -
# 53 513 pedestrian 0 - -
# 53 518 pedestrian 0 - -
# 53 532 cyclist 0 - -
# 53 535 cyclist 0 - -
# 53 536 pedestrian 0 - -
# 53 537 pedestrian 0 - -
# 53 540 cyclist 0 - -
# 53 542 cyclist 0 - -
# 53 543 cyclist 1 - -
# 53 544 pedestrian 0 - -
# 53 546 pedestrian 0 - -
# 53 547 pedestrian 0 - -
# 53 548 pedestrian 0 - -
# 53 549 pedestrian 0 - -
# 53 551 pedestrian 1 - -
# 53 552 pedestrian 0 - -
# 53 553 pedestrian 0 - -
# 53 554 pedestrian 0 - -
# 53 555 vehicle 0 - -
# 54 487 pedestrian 0 - -
# 54 493 pedestrian 0 - -
# 54 503 pedestrian 0 - -
# 54 506 pedestrian 0 - -
# 54 513 pedestrian 0 - -
# 54 518 pedestrian 0 - -
# 54 532 cyclist 0 - -
# 54 535 cyclist 0 - -
# 54 536 pedestrian 0 - -
# 54 537 pedestrian 0 - -
# 54 540 cyclist 0 - -
# 54 542 cyclist 0 - -
# 54 544 pedestrian 0 - -
# 54 546 pedestrian 0 - -
# 54 547 pedestrian 0 - -
# 54 548 pedestrian 0 - -
# 54 549 pedestrian 0 - -
# 54 552 pedestrian 0 - -
# 54 553 pedestrian 0 - -
# 54 554 pedestrian 0 - -
# 54 555 vehicle 0 - -
# 54 556 vehicle 0 - -
# 54 557 pedestrian 0 - -
# 55 487 pedestrian 0 - -
# 55 493 pedestrian 0 - -
# 55 503 pedestrian 0 - -
# 55 506 pedestrian 0 - -
# 55 513 pedestrian 0 - -
# 55 518 cyclist 0 - -
# 55 532 cyclist 1 - -
# 55 535 cyclist 0 - -
# 55 536 pedestrian 0 - -
# 55 537 pedestrian 0 - -
# 55 540 cyclist 0 - -
# 55 542 cyclist 1 - -
# 55 544 pedestrian 1 - -
# 55 546 pedestrian 1 - -
# 55 547 pedestrian 0 - -
# 55 548 pedestrian 0 - -
# 55 549 pedestrian 0 - -
# 55 552 pedestrian 0 - -
# 55 553 pedestrian 0 - -
# 55 554 pedestrian 0 - -
# 55 555 vehicle 0 - -
# 55 556 vehicle 0 - -
# 55 557 pedestrian 0 - -
# 55 558 pedestrian 0 - -
# 55 559 pedestrian 0 - -
# 56 487 pedestrian 0 - -
# 56 493 pedestrian 0 - -
# 56 503 pedestrian 0 - -
# 56 506 pedestrian 0 - -
# 56 513 pedestrian 0 - -
# 56 518 pedestrian 0 - -
# 56 535 cyclist 0 - -
# 56 536 pedestrian 0 - -
# 56 537 pedestrian 0 - -
# 56 540 cyclist 0 - -
# 56 547 pedestrian 0 - -
# 56 548 pedestrian 0 - -
# 56 549 pedestrian 1 - -
# 56 552 pedestrian 0 - -
# 56 553 pedestrian 0 - -
# 56 554 pedestrian 0 - -
# 56 555 vehicle 0 - -
# 56 556 vehicle 0 - -
# 56 557 pedestrian 0 - -
# 56 558 pedestrian 0 - -
# 56 559 pedestrian 0 - -
# 56 560 pedestrian 0 - -
# 57 487 pedestrian 0 - -
# 57 493 pedestrian 0 - -
# 57 503 pedestrian 0 - -
# 57 506 pedestrian 1 - -
# 57 513 pedestrian 0 - -
# 57 518 pedestrian 0 - -
# 57 535 cyclist 1 - -
# 57 536 pedestrian 0 - -
# 57 537 pedestrian 0 - -
# 57 540 cyclist 0 - -
# 57 547 pedestrian 0 - -
# 57 548 pedestrian 0 - -
# 57 552 pedestrian 0 - -
# 57 553 pedestrian 0 - -
# 57 554 pedestrian 0 - -
# 57 555 vehicle 1 - -
# 57 556 vehicle 0 - -
# 57 557 pedestrian 0 - -
# 57 558 pedestrian 0 - -
# 57 559 pedestrian 0 - -
# 57 560 pedestrian 0 - -
# 57 561 cyclist 0 - -
# 57 562 pedestrian 0 - -
# 58 487 pedestrian 0 - -
# 58 493 pedestrian 0 - -
# 58 503 pedestrian 0 - -
# 58 513 pedestrian 0 - -
# 58 518 pedestrian 0 - -
# 58 536 pedestrian 0 - -
# 58 537 pedestrian 0 - -
# 58 540 cyclist 0 - -
# 58 547 pedestrian 0 - -
# 58 548 pedestrian 0 - -
# 58 552 pedestrian 0 - -
# 58 553 pedestrian 1 - -
# 58 554 pedestrian 0 - -
# 58 556 vehicle 0 - -
# 58 557 pedestrian 0 - -
# 58 558 pedestrian 0 - -
# 58 559 pedestrian 0 - -
# 58 560 pedestrian 0 - -
# 58 561 cyclist 0 - -
# 58 562 pedestrian 0 - -
# 58 563 pedestrian 0 - -
# 58 564 pedestrian 0 - -
# 58 565 pedestrian 0 - -
# 58 566 pedestrian 0 - -
# 59 487 pedestrian 0 - -
# 59 493 pedestrian 0 - -
# 59 503 pedestrian 0 - -
# 59 513 pedestrian 0 - -
# 59 518 pedestrian 0 - -
# 59 536 pedestrian 0 - -
# 59 537 pedestrian 0 - -
# 59 540 cyclist 0 - -
# 59 547 pedestrian 0 - -
# 59 548 pedestrian 0 - -
# 59 552 pedestrian 0 - -
# 59 554 pedestrian 0 - -
# 59 556 vehicle 0 - -
# 59 557 pedestrian 1 - -
# 59 558 pedestrian 0 - -
# 59 559 pedestrian 0 - -
# 59 560 pedestrian 0 - -
# 59 561 cyclist 0 - -
# 59 562 cyclist 0 - -
# 59 563 pedestrian 0 - -
# 59 564 pedestrian 0 - -
# 59 565 pedestrian 0 - -
# 59 566 pedestrian 0 - -
# 60 487 pedestrian 0 - -
# 60 493 pedestrian 0 - -
# 60 503 pedestrian 0 - -
# 60 513 pedestrian 0 - -
# 60 518 pedestrian 0 - -
# 60 536 pedestrian 0 - -
# 60 537 pedestrian 0 - -
# 60 540 cyclist 0 - -
# 60 547 pedestrian 0 - -
# 60 548 pedestrian 0 - -
# 60 552 pedestrian 0 - -
# 60 554 pedestrian 0 - -
# 60 556 cyclist 0 - -
# 60 558 pedestrian 0 - -
# 60 559 pedestrian 0 - -
# 60 560 pedestrian 0 - -
# 60 561 cyclist 0 - -
# 60 562 cyclist 0 - -
# 60 563 pedestrian 0 - -
# 60 564 pedestrian 0 - -
# 60 565 pedestrian 0 - -
# 60 566 pedestrian 0 - -
# 60 567 cyclist 0 - -
# 60 568 pedestrian 0 - -
# 60 569 pedestrian 0 - -
# 61 487 pedestrian 0 - -
# 61 493 pedestrian 0 - -
# 61 503 pedestrian 0 - -
# 61 513 pedestrian 0 - -
# 61 518 pedestrian 0 - -
# 61 536 pedestrian 0 - -
# 61 537 pedestrian 0 - -
# 61 540 cyclist 0 - -
# 61 547 pedestrian 0 - -
# 61 548 pedestrian 0 - -
# 61 552 pedestrian 1 - -
# 61 554 pedestrian 0 - -
# 61 556 vehicle 0 - -
# 61 558 pedestrian 0 - -
# 61 559 pedestrian 0 - -
# 61 560 pedestrian 0 - -
# 61 561 cyclist 0 - -
# 61 562 pedestrian 0 - -
# 61 563 pedestrian 0 - -
# 61 564 pedestrian 0 - -
# 61 565 pedestrian 0 - -
# 61 566 pedestrian 0 - -
# 61 567 cyclist 0 - -
# 61 568 pedestrian 0 - -
# 61 569 pedestrian 0 - -
# 61 570 cyclist 0 - -
# 62 487 pedestrian 0 - -
# 62 493 pedestrian 0 - -
# 62 503 pedestrian 0 - -
# 62 513 pedestrian 0 - -
# 62 518 pedestrian 0 - -
# 62 536 pedestrian 0 - -
# 62 537 pedestrian 0 - -
# 62 540 cyclist 0 - -
# 62 547 pedestrian 0 - -
# 62 548 pedestrian 0 - -
# 62 552 pedestrian 0 - -
# 62 554 pedestrian 0 - -
# 62 556 vehicle 0 - -
# 62 558 pedestrian 0 - -
# 62 559 pedestrian 0 - -
# 62 560 pedestrian 0 - -
# 62 561 cyclist 0 - -
# 62 562 pedestrian 0 - -
# 62 563 pedestrian 0 - -
# 62 564 pedestrian 0 - -
# 62 565 pedestrian 0 - -
# 62 566 pedestrian 0 - -
# 62 567 cyclist 0 - -
# 62 568 pedestrian 0 - -
# 62 569 pedestrian 0 - -
# 62 570 cyclist 0 - -
# 63 487 pedestrian 0 - -
# 63 493 pedestrian 0 - -
# 63 503 pedestrian 0 - -
# 63 513 pedestrian 0 - -
# 63 518 pedestrian 0 - -
# 63 536 pedestrian 0 - -
# 63 537 pedestrian 0 - -
# 63 540 cyclist 0 - -
# 63 547 pedestrian 0 - -
# 63 548 pedestrian 0 - -
# 63 552 pedestrian 0 - -
# 63 554 pedestrian 0 - -
# 63 556 cyclist 0 - -
# 63 558 pedestrian 0 - -
# 63 559 pedestrian 0 - -
# 63 560 pedestrian 0 - -
# 63 561 cyclist 0 - -
# 63 562 pedestrian 0 - -
# 63 563 pedestrian 0 - -
# 63 564 pedestrian 0 - -
# 63 565 pedestrian 1 - -
# 63 566 pedestrian 1 - -
# 63 567 cyclist 0 - -
# 63 568 pedestrian 0 - -
# 63 569 pedestrian 0 - -
# 63 570 cyclist 0 - -
# 63 571 pedestrian 0 - -
# 63 572 vehicle 0 - -
# 63 573 cyclist 0 - -
# 63 574 cyclist 0 - -
# 64 487 pedestrian 0 - -
# 64 493 pedestrian 0 - -
# 64 503 pedestrian 0 - -
# 64 513 pedestrian 0 - -
# 64 518 pedestrian 0 - -
# 64 536 cyclist 0 - -
# 64 537 pedestrian 0 - -
# 64 540 cyclist 0 - -
# 64 547 pedestrian 0 - -
# 64 548 pedestrian 0 - -
# 64 552 pedestrian 0 - -
# 64 554 pedestrian 0 - -
# 64 556 vehicle 0 - -
# 64 558 pedestrian 0 - -
# 64 559 pedestrian 0 - -
# 64 560 pedestrian 0 - -
# 64 561 cyclist 0 - -
# 64 562 pedestrian 0 - -
# 64 563 pedestrian 0 - -
# 64 564 pedestrian 1 - -
# 64 567 cyclist 0 - -
# 64 568 pedestrian 0 - -
# 64 569 pedestrian 0 - -
# 64 570 cyclist 0 - -
# 64 571 pedestrian 0 - -
# 64 572 vehicle 0 - -
# 64 573 cyclist 0 - -
# 64 574 pedestrian 0 - -
# 65 487 pedestrian 0 - -
# 65 493 pedestrian 0 - -
# 65 503 pedestrian 0 - -
# 65 513 pedestrian 0 - -
# 65 518 pedestrian 0 - -
# 65 536 cyclist 0 - -
# 65 537 pedestrian 0 - -
# 65 540 cyclist 1 - -
# 65 547 pedestrian 0 - -
# 65 548 pedestrian 0 - -
# 65 552 pedestrian 0 - -
# 65 554 pedestrian 0 - -
# 65 556 cyclist 0 - -
# 65 558 pedestrian 0 - -
# 65 559 pedestrian 0 - -
# 65 560 pedestrian 0 - -
# 65 561 cyclist 0 - -
# 65 562 pedestrian 0 - -
# 65 563 pedestrian 0 - -
# 65 567 cyclist 0 - -
# 65 568 pedestrian 1 - -
# 65 569 pedestrian 1 - -
# 65 570 vehicle 0 - -
# 65 571 pedestrian 0 - -
# 65 572 vehicle 0 - -
# 65 573 cyclist 0 - -
# 65 574 pedestrian 0 - -
# 65 575 pedestrian 0 - -
# 65 576 pedestrian 0 - -
# 66 487 pedestrian 0 - -
# 66 493 pedestrian 0 - -
# 66 503 pedestrian 0 - -
# 66 513 pedestrian 0 - -
# 66 518 pedestrian 0 - -
# 66 536 cyclist 0 - -
# 66 537 pedestrian 0 - -
# 66 547 pedestrian 0 - -
# 66 548 pedestrian 0 - -
# 66 552 pedestrian 0 - -
# 66 554 pedestrian 0 - -
# 66 556 cyclist 0 - -
# 66 558 pedestrian 0 - -
# 66 559 pedestrian 0 - -
# 66 560 pedestrian 0 - -
# 66 561 cyclist 0 - -
# 66 562 pedestrian 1 - -
# 66 563 pedestrian 1 - -
# 66 567 cyclist 0 - -
# 66 570 vehicle 0 - -
# 66 571 pedestrian 0 - -
# 66 572 vehicle 0 - -
# 66 573 cyclist 0 - -
# 66 574 pedestrian 0 - -
# 66 575 pedestrian 0 - -
# 66 576 pedestrian 0 - -
# 67 487 pedestrian 0 - -
# 67 493 pedestrian 0 - -
# 67 503 pedestrian 0 - -
# 67 513 pedestrian 0 - -
# 67 518 pedestrian 1 - -
# 67 536 cyclist 0 - -
# 67 537 pedestrian 0 - -
# 67 547 pedestrian 0 - -
# 67 548 pedestrian 0 - -
# 67 552 pedestrian 0 - -
# 67 554 pedestrian 0 - -
# 67 556 cyclist 0 - -
# 67 558 pedestrian 0 - -
# 67 559 pedestrian 0 - -
# 67 560 pedestrian 0 - -
# 67 561 cyclist 0 - -
# 67 567 cyclist 0 - -
# 67 570 vehicle 0 - -
# 67 571 pedestrian 0 - -
# 67 572 vehicle 0 - -
# 67 573 cyclist 0 - -
# 67 574 pedestrian 0 - -
# 67 575 pedestrian 0 - -
# 67 576 pedestrian 0 - -
# 67 577 pedestrian 0 - -
# 67 578 pedestrian 0 - -
# 68 487 pedestrian 1 - -
# 68 493 pedestrian 0 - -
# 68 503 pedestrian 0 - -
# 68 513 pedestrian 0 - -
# 68 536 cyclist 0 - -
# 68 537 pedestrian 0 - -
# 68 547 pedestrian 0 - -
# 68 548 pedestrian 0 - -
# 68 552 pedestrian 0 - -
# 68 554 pedestrian 0 - -
# 68 556 cyclist 0 - -
# 68 558 pedestrian 0 - -
# 68 559 pedestrian 0 - -
# 68 560 pedestrian 0 - -
# 68 561 cyclist 0 - -
# 68 567 cyclist 0 - -
# 68 570 vehicle 0 - -
# 68 571 pedestrian 1 - -
# 68 572 vehicle 0 - -
# 68 573 cyclist 0 - -
# 68 574 pedestrian 0 - -
# 68 575 pedestrian 0 - -
# 68 576 pedestrian 0 - -
# 68 577 pedestrian 0 - -
# 68 578 pedestrian 0 - -
# 69 493 pedestrian 0 - -
# 69 503 pedestrian 0 - -
# 69 513 pedestrian 0 - -
# 69 536 cyclist 0 - -
# 69 537 pedestrian 0 - -
# 69 547 pedestrian 0 - -
# 69 548 pedestrian 0 - -
# 69 552 pedestrian 0 - -
# 69 554 pedestrian 0 - -
# 69 556 cyclist 0 - -
# 69 558 pedestrian 0 - -
# 69 559 pedestrian 0 - -
# 69 560 pedestrian 0 - -
# 69 561 cyclist 0 - -
# 69 567 cyclist 0 - -
# 69 570 vehicle 0 - -
# 69 572 vehicle 0 - -
# 69 573 cyclist 0 - -
# 69 574 pedestrian 0 - -
# 69 575 pedestrian 0 - -
# 69 576 pedestrian 0 - -
# 69 577 pedestrian 0 - -
# 69 578 pedestrian 0 - -
# 69 579 pedestrian 0 - -
# 69 580 pedestrian 0 - -
# 70 493 pedestrian 0 - -
# 70 503 pedestrian 0 - -
# 70 513 pedestrian 1 - -
# 70 536 pedestrian 0 - -
# 70 537 pedestrian 0 - -
# 70 547 pedestrian 0 - -
# 70 548 pedestrian 0 - -
# 70 552 pedestrian 0 - -
# 70 554 pedestrian 0 - -
# 70 556 cyclist 0 - -
# 70 558 pedestrian 0 - -
# 70 559 pedestrian 0 - -
# 70 560 pedestrian 0 - -
# 70 561 cyclist 0 - -
# 70 567 cyclist 0 - -
# 70 570 vehicle 0 - -
# 70 572 vehicle 0 - -
# 70 573 cyclist 0 - -
# 70 574 cyclist 0 - -
# 70 575 pedestrian 1 - -
# 70 576 pedestrian 0 - -
# 70 577 pedestrian 0 - -
# 70 578 pedestrian 0 - -
# 70 579 pedestrian 0 - -
# 70 580 pedestrian 0 - -
# 71 493 pedestrian 0 - -
# 71 503 pedestrian 0 - -
# 71 536 pedestrian 0 - -
# 71 537 pedestrian 0 - -
# 71 547 pedestrian 0 - -
# 71 548 pedestrian 0 - -
# 71 552 pedestrian 0 - -
# 71 554 pedestrian 0 - -
# 71 556 cyclist 0 - -
# 71 558 pedestrian 0 - -
# 71 559 pedestrian 0 - -
# 71 560 pedestrian 0 - -
# 71 561 cyclist 0 - -
# 71 567 cyclist 0 - -
# 71 570 vehicle 0 - -
# 71 572 vehicle 0 - -
# 71 573 cyclist 0 - -
# 71 574 cyclist 0 - -
# 71 576 pedestrian 0 - -
# 71 577 pedestrian 0 - -
# 71 578 pedestrian 0 - -
# 71 579 pedestrian 0 - -
# 71 580 pedestrian 0 - -
# 72 493 pedestrian 0 - -
# 72 503 pedestrian 1 - -
# 72 536 cyclist 0 - -
# 72 537 pedestrian 0 - -
# 72 547 pedestrian 0 - -
# 72 548 pedestrian 0 - -
# 72 552 pedestrian 0 - -
# 72 554 pedestrian 0 - -
# 72 556 cyclist 0 - -
# 72 558 pedestrian 0 - -
# 72 559 pedestrian 0 - -
# 72 560 pedestrian 0 - -
# 72 561 cyclist 0 - -
# 72 567 cyclist 0 - -
# 72 570 vehicle 0 - -
# 72 572 vehicle 0 - -
# 72 573 cyclist 0 - -
# 72 574 cyclist 0 - -
# 72 576 pedestrian 0 - -
# 72 577 pedestrian 0 - -
# 72 578 pedestrian 0 - -
# 72 579 pedestrian 0 - -
# 72 580 pedestrian 0 - -
# 73 493 pedestrian 0 - -
# 73 536 cyclist 0 - -
# 73 537 pedestrian 0 - -
# 73 547 pedestrian 0 - -
# 73 548 pedestrian 0 - -
# 73 552 pedestrian 0 - -
# 73 554 pedestrian 0 - -
# 73 556 cyclist 0 - -
# 73 558 pedestrian 0 - -
# 73 559 pedestrian 0 - -
# 73 560 pedestrian 1 - -
# 73 561 cyclist 0 - -
# 73 567 cyclist 0 - -
# 73 570 vehicle 0 - -
# 73 572 vehicle 0 - -
# 73 573 cyclist 0 - -
# 73 574 pedestrian 0 - -
# 73 576 pedestrian 0 - -
# 73 577 pedestrian 0 - -
# 73 578 pedestrian 0 - -
# 73 579 pedestrian 0 - -
# 73 580 pedestrian 0 - -
# 74 493 pedestrian 0 - -
# 74 536 cyclist 0 - -
# 74 537 pedestrian 0 - -
# 74 547 pedestrian 0 - -
# 74 548 pedestrian 0 - -
# 74 552 pedestrian 0 - -
# 74 554 pedestrian 0 - -
# 74 556 cyclist 0 - -
# 74 558 pedestrian 0 - -
# 74 559 pedestrian 0 - -
# 74 561 cyclist 0 - -
# 74 567 cyclist 0 - -
# 74 570 vehicle 0 - -
# 74 572 vehicle 0 - -
# 74 573 cyclist 0 - -
# 74 574 pedestrian 0 - -
# 74 576 pedestrian 0 - -
# 74 577 pedestrian 0 - -
# 74 578 pedestrian 0 - -
# 74 579 pedestrian 1 - -
# 74 580 pedestrian 1 - -
# 74 581 pedestrian 0 - -
# 75 493 pedestrian 0 - -
# 75 536 cyclist 0 - -
# 75 537 pedestrian 0 - -
# 75 547 pedestrian 0 - -
# 75 548 pedestrian 0 - -
# 75 552 pedestrian 0 - -
# 75 554 pedestrian 0 - -
# 75 556 cyclist 0 - -
# 75 558 pedestrian 0 - -
# 75 559 pedestrian 0 - -
# 75 561 cyclist 0 - -
# 75 567 cyclist 0 - -
# 75 570 vehicle 0 - -
# 75 572 vehicle 0 - -
# 75 573 cyclist 0 - -
# 75 574 pedestrian 0 - -
# 75 576 pedestrian 0 - -
# 75 577 pedestrian 0 - -
# 75 578 pedestrian 0 - -
# 75 581 pedestrian 0 - -
# 75 582 cyclist 0 - -
# 76 493 pedestrian 0 - -
# 76 536 cyclist 0 - -
# 76 537 pedestrian 0 - -
# 76 547 pedestrian 0 - -
# 76 548 pedestrian 1 - -
# 76 552 pedestrian 0 - -
# 76 554 pedestrian 0 - -
# 76 556 cyclist 0 - -
# 76 558 pedestrian 0 - -
# 76 559 pedestrian 0 - -
# 76 561 cyclist 0 - -
# 76 567 cyclist 0 - -
# 76 570 cyclist 0 - -
# 76 572 vehicle 0 - -
# 76 573 cyclist 0 - -
# 76 574 pedestrian 0 - -
# 76 576 pedestrian 0 - -
# 76 577 pedestrian 1 - -
# 76 578 pedestrian 0 - -
# 76 581 pedestrian 0 - -
# 76 582 cyclist 0 - -
# 76 583 pedestrian 0 - -
# 76 584 pedestrian 0 - -
# 77 493 pedestrian 0 - -
# 77 536 cyclist 0 - -
# 77 537 pedestrian 0 - -
# 77 547 pedestrian 0 - -
# 77 552 pedestrian 1 - -
# 77 554 pedestrian 0 - -
# 77 556 cyclist 0 - -
# 77 558 pedestrian 0 - -
# 77 559 pedestrian 0 - -
# 77 561 cyclist 0 - -
# 77 567 cyclist 0 - -
# 77 570 cyclist 0 - -
# 77 572 vehicle 0 - -
# 77 573 cyclist 0 - -
# 77 574 pedestrian 0 - -
# 77 576 pedestrian 0 - -
# 77 578 pedestrian 0 - -
# 77 581 pedestrian 0 - -
# 77 582 cyclist 0 - -
# 77 583 pedestrian 0 - -
# 77 584 pedestrian 0 - -
# 78 493 pedestrian 0 - -
# 78 536 cyclist 0 - -
# 78 537 pedestrian 0 - -
# 78 547 pedestrian 0 - -
# 78 554 pedestrian 0 - -
# 78 556 cyclist 0 - -
# 78 558 pedestrian 0 - -
# 78 559 pedestrian 0 - -
# 78 561 cyclist 0 - -
# 78 567 cyclist 0 - -
# 78 570 cyclist 0 - -
# 78 572 vehicle 0 - -
# 78 573 cyclist 0 - -
# 78 574 pedestrian 0 - -
# 78 576 pedestrian 0 - -
# 78 578 pedestrian 1 - -
# 78 581 pedestrian 0 - -
# 78 582 cyclist 0 - -
# 78 583 pedestrian 0 - -
# 78 584 pedestrian 0 - -
# 79 493 pedestrian 0 - -
# 79 536 cyclist 0 - -
# 79 537 pedestrian 0 - -
# 79 547 pedestrian 0 - -
# 79 554 pedestrian 0 - -
# 79 556 cyclist 0 - -
# 79 558 pedestrian 0 - -
# 79 559 pedestrian 0 - -
# 79 561 cyclist 0 - -
# 79 567 cyclist 0 - -
# 79 570 cyclist 0 - -
# 79 572 vehicle 0 - -
# 79 573 cyclist 0 - -
# 79 574 pedestrian 0 - -
# 79 576 pedestrian 0 - -
# 79 581 pedestrian 1 - -
# 79 582 cyclist 0 - -
# 79 583 pedestrian 0 - -
# 79 584 pedestrian 0 - -
# 79 585 pedestrian 0 - -
# 79 586 pedestrian 0 - -
# 80 493 pedestrian 0 - -
# 80 536 cyclist 0 - -
# 80 537 pedestrian 0 - -
# 80 547 pedestrian 0 - -
# 80 554 pedestrian 0 - -
# 80 556 cyclist 1 - -
# 80 558 pedestrian 0 - -
# 80 559 pedestrian 0 - -
# 80 561 cyclist 0 - -
# 80 567 cyclist 1 - -
# 80 570 cyclist 0 - -
# 80 572 vehicle 0 - -
# 80 573 cyclist 0 - -
# 80 574 pedestrian 0 - -
# 80 576 pedestrian 0 - -
# 80 582 cyclist 0 - -
# 80 583 pedestrian 0 - -
# 80 584 pedestrian 0 - -
# 80 585 pedestrian 0 - -
# 80 586 pedestrian 0 - -
# 80 587 pedestrian 0 - -
# 81 493 pedestrian 0 - -
# 81 536 pedestrian 0 - -
# 81 537 pedestrian 0 - -
# 81 547 pedestrian 0 - -
# 81 554 pedestrian 0 - -
# 81 558 pedestrian 0 - -
# 81 559 pedestrian 0 - -
# 81 561 cyclist 0 - -
# 81 570 cyclist 0 - -
# 81 572 vehicle 0 - -
# 81 573 cyclist 0 - -
# 81 574 cyclist 0 - -
# 81 576 pedestrian 0 - -
# 81 582 cyclist 0 - -
# 81 583 pedestrian 1 - -
# 81 584 pedestrian 0 - -
# 81 585 pedestrian 0 - -
# 81 586 pedestrian 0 - -
# 81 587 pedestrian 0 - -
# 82 493 pedestrian 0 - -
# 82 536 pedestrian 0 - -
# 82 537 pedestrian 0 - -
# 82 547 pedestrian 0 - -
# 82 554 pedestrian 0 - -
# 82 558 pedestrian 0 - -
# 82 559 pedestrian 0 - -
# 82 561 cyclist 0 - -
# 82 570 cyclist 0 - -
# 82 572 vehicle 0 - -
# 82 573 cyclist 0 - -
# 82 574 cyclist 0 - -
# 82 576 pedestrian 0 - -
# 82 582 cyclist 0 - -
# 82 584 pedestrian 0 - -
# 82 585 pedestrian 0 - -
# 82 586 pedestrian 0 - -
# 82 587 pedestrian 0 - -
# 82 588 pedestrian 0 - -
# 83 493 pedestrian 0 - -
# 83 536 pedestrian 0 - -
# 83 537 pedestrian 0 - -
# 83 547 pedestrian 0 - -
# 83 554 pedestrian 0 - -
# 83 558 pedestrian 0 - -
# 83 559 pedestrian 0 - -
# 83 561 cyclist 0 - -
# 83 570 cyclist 0 - -
# 83 572 vehicle 0 - -
# 83 573 cyclist 0 - -
# 83 574 cyclist 0 - -
# 83 576 pedestrian 0 - -
# 83 582 cyclist 0 - -
# 83 584 pedestrian 0 - -
# 83 585 pedestrian 0 - -
# 83 586 pedestrian 0 - -
# 83 587 pedestrian 0 - -
# 83 588 pedestrian 0 - -
# 84 493 pedestrian 0 - -
# 84 536 pedestrian 0 - -
# 84 537 pedestrian 0 - -
# 84 547 pedestrian 0 - -
# 84 554 pedestrian 0 - -
# 84 558 pedestrian 0 - -
# 84 559 pedestrian 0 - -
# 84 561 cyclist 0 - -
# 84 570 cyclist 0 - -
# 84 572 vehicle 0 - -
# 84 573 cyclist 0 - -
# 84 574 cyclist 0 - -
# 84 576 pedestrian 0 - -
# 84 582 cyclist 0 - -
# 84 584 pedestrian 0 - -
# 84 585 pedestrian 0 - -
# 84 586 pedestrian 0 - -
# 84 587 pedestrian 0 - -
# 84 588 pedestrian 0 - -
# 85 493 pedestrian 0 - -
# 85 536 pedestrian 0 - -
# 85 537 pedestrian 0 - -
# 85 547 pedestrian 0 - -
# 85 554 pedestrian 0 - -
# 85 558 pedestrian 0 - -
# 85 559 pedestrian 0 - -
# 85 561 cyclist 0 - -
# 85 570 cyclist 0 - -
# 85 572 vehicle 0 - -
# 85 573 cyclist 0 - -
# 85 574 cyclist 0 - -
# 85 576 pedestrian 0 - -
# 85 582 cyclist 0 - -
# 85 584 pedestrian 0 - -
# 85 585 pedestrian 0 - -
# 85 586 pedestrian 0 - -
# 85 587 pedestrian 0 - -
# 85 588 pedestrian 0 - -
# 86 493 pedestrian 0 - -
# 86 536 pedestrian 0 - -
# 86 537 pedestrian 0 - -
# 86 547 pedestrian 0 - -
# 86 554 pedestrian 0 - -
# 86 558 pedestrian 0 - -
# 86 559 pedestrian 0 - -
# 86 561 cyclist 0 - -
# 86 570 cyclist 0 - -
# 86 572 vehicle 0 - -
# 86 573 cyclist 0 - -
# 86 574 cyclist 0 - -
# 86 576 pedestrian 1 - -
# 86 582 cyclist 0 - -
# 86 584 pedestrian 0 - -
# 86 585 pedestrian 0 - -
# 86 586 pedestrian 0 - -
# 86 587 pedestrian 0 - -
# 86 588 pedestrian 0 - -
# 87 493 pedestrian 0 - -
# 87 536 pedestrian 0 - -
# 87 537 pedestrian 0 - -
# 87 547 pedestrian 0 - -
# 87 554 pedestrian 0 - -
# 87 558 pedestrian 0 - -
# 87 559 pedestrian 0 - -
# 87 561 cyclist 0 - -
# 87 570 cyclist 0 - -
# 87 572 vehicle 0 - -
# 87 573 cyclist 0 - -
# 87 574 cyclist 0 - -
# 87 582 cyclist 0 - -
# 87 584 pedestrian 0 - -
# 87 585 pedestrian 0 - -
# 87 586 pedestrian 0 - -
# 87 587 pedestrian 1 - -
# 87 588 pedestrian 1 - -
# 88 493 pedestrian 0 - -
# 88 536 pedestrian 0 - -
# 88 537 pedestrian 1 - -
# 88 547 pedestrian 0 - -
# 88 554 pedestrian 0 - -
# 88 558 pedestrian 0 - -
# 88 559 pedestrian 0 - -
# 88 561 cyclist 0 - -
# 88 570 cyclist 0 - -
# 88 572 vehicle 0 - -
# 88 573 cyclist 0 - -
# 88 574 cyclist 0 - -
# 88 582 cyclist 0 - -
# 88 584 pedestrian 0 - -
# 88 585 pedestrian 0 - -
# 88 586 pedestrian 0 - -
# 88 589 pedestrian 0 - -
# 89 493 pedestrian 0 - -
# 89 536 pedestrian 1 - -
# 89 547 pedestrian 0 - -
# 89 554 pedestrian 0 - -
# 89 558 pedestrian 0 - -
# 89 559 pedestrian 1 - -
# 89 561 cyclist 0 - -
# 89 570 cyclist 0 - -
# 89 572 vehicle 0 - -
# 89 573 cyclist 0 - -
# 89 574 cyclist 0 - -
# 89 582 cyclist 0 - -
# 89 584 pedestrian 0 - -
# 89 585 pedestrian 0 - -
# 89 586 pedestrian 0 - -
# 89 589 pedestrian 0 - -
# 89 590 pedestrian 0 - -
# 90 493 pedestrian 0 - -
# 90 547 pedestrian 0 - -
# 90 554 pedestrian 0 - -
# 90 558 pedestrian 0 - -
# 90 561 cyclist 0 - -
# 90 570 cyclist 0 - -
# 90 572 vehicle 0 - -
# 90 573 cyclist 0 - -
# 90 574 cyclist 0 - -
# 90 582 cyclist 0 - -
# 90 584 pedestrian 0 - -
# 90 585 pedestrian 0 - -
# 90 586 pedestrian 1 - -
# 90 589 pedestrian 0 - -
# 90 590 pedestrian 0 - -
# 90 591 pedestrian 0 - -
# 91 493 pedestrian 0 - -
# 91 547 pedestrian 0 - -
# 91 554 pedestrian 0 - -
# 91 558 pedestrian 0 - -
# 91 561 cyclist 0 - -
# 91 570 cyclist 0 - -
# 91 572 vehicle 0 - -
# 91 573 cyclist 0 - -
# 91 574 cyclist 0 - -
# 91 582 cyclist 0 - -
# 91 584 pedestrian 0 - -
# 91 585 pedestrian 1 - -
# 91 589 pedestrian 0 - -
# 91 590 pedestrian 0 - -
# 91 591 pedestrian 0 - -
# 91 592 pedestrian 0 - -
# 92 493 pedestrian 0 - -
# 92 547 pedestrian 0 - -
# 92 554 pedestrian 0 - -
# 92 558 pedestrian 0 - -
# 92 561 cyclist 0 - -
# 92 570 cyclist 0 - -
# 92 572 vehicle 0 - -
# 92 573 cyclist 0 - -
# 92 574 cyclist 0 - -
# 92 582 cyclist 0 - -
# 92 584 pedestrian 0 - -
# 92 589 pedestrian 0 - -
# 92 590 pedestrian 0 - -
# 92 591 pedestrian 0 - -
# 92 592 cyclist 0 - -
# 93 493 pedestrian 0 - -
# 93 547 pedestrian 0 - -
# 93 554 pedestrian 0 - -
# 93 558 pedestrian 0 - -
# 93 561 cyclist 0 - -
# 93 570 cyclist 0 - -
# 93 572 vehicle 0 - -
# 93 573 cyclist 0 - -
# 93 574 cyclist 0 - -
# 93 582 cyclist 0 - -
# 93 584 pedestrian 0 - -
# 93 589 pedestrian 0 - -
# 93 590 pedestrian 0 - -
# 93 591 pedestrian 0 - -
# 93 592 cyclist 0 - -
# 93 593 pedestrian 0 - -
# 94 493 pedestrian 0 - -
# 94 547 pedestrian 0 - -
# 94 554 pedestrian 0 - -
# 94 558 pedestrian 0 - -
# 94 561 cyclist 0 - -
# 94 570 cyclist 0 - -
# 94 572 vehicle 0 - -
# 94 573 cyclist 0 - -
# 94 574 cyclist 0 - -
# 94 582 cyclist 0 - -
# 94 584 pedestrian 0 - -
# 94 589 pedestrian 0 - -
# 94 590 pedestrian 0 - -
# 94 591 pedestrian 0 - -
# 94 592 cyclist 0 - -
# 94 593 pedestrian 0 - -
# 94 594 pedestrian 0 - -
# 95 493 pedestrian 0 - -
# 95 547 pedestrian 0 - -
# 95 554 pedestrian 0 - -
# 95 558 pedestrian 1 - -
# 95 561 cyclist 0 - -
# 95 570 cyclist 0 - -
# 95 572 vehicle 0 - -
# 95 573 cyclist 0 - -
# 95 574 cyclist 0 - -
# 95 582 cyclist 0 - -
# 95 584 pedestrian 0 - -
# 95 589 pedestrian 1 - -
# 95 590 pedestrian 1 - -
# 95 591 pedestrian 0 - -
# 95 592 cyclist 0 - -
# 95 593 pedestrian 0 - -
# 95 594 pedestrian 0 - -
# 95 595 pedestrian 0 - -
# 96 493 pedestrian 0 - -
# 96 547 pedestrian 0 - -
# 96 554 pedestrian 0 - -
# 96 561 cyclist 0 - -
# 96 570 cyclist 0 - -
# 96 572 vehicle 0 - -
# 96 573 cyclist 0 - -
# 96 574 cyclist 1 - -
# 96 582 cyclist 0 - -
# 96 584 pedestrian 0 - -
# 96 591 pedestrian 0 - -
# 96 592 cyclist 0 - -
# 96 593 pedestrian 0 - -
# 96 594 pedestrian 0 - -
# 96 595 pedestrian 0 - -
# 96 596 pedestrian 0 - -
# 97 493 pedestrian 0 - -
# 97 547 pedestrian 0 - -
# 97 554 pedestrian 0 - -
# 97 561 cyclist 0 - -
# 97 570 cyclist 0 - -
# 97 572 vehicle 0 - -
# 97 573 cyclist 0 - -
# 97 574 pedestrian 0 - -
# 97 582 cyclist 0 - -
# 97 584 pedestrian 0 - -
# 97 591 pedestrian 0 - -
# 97 592 cyclist 0 - -
# 97 593 pedestrian 0 - -
# 97 594 pedestrian 0 - -
# 97 595 pedestrian 0 - -
# 97 596 pedestrian 0 - -
# 98 493 pedestrian 0 - -
# 98 547 pedestrian 0 - -
# 98 554 pedestrian 0 - -
# 98 561 cyclist 0 - -
# 98 570 cyclist 0 - -
# 98 572 vehicle 0 - -
# 98 573 cyclist 0 - -
# 98 574 pedestrian 0 - -
# 98 582 cyclist 0 - -
# 98 584 pedestrian 0 - -
# 98 591 pedestrian 0 - -
# 98 592 cyclist 0 - -
# 98 593 pedestrian 0 - -
# 98 594 pedestrian 0 - -
# 98 595 pedestrian 0 - -
# 98 596 pedestrian 0 - -
# 99 493 pedestrian 0 - -
# 99 547 pedestrian 0 - -
# 99 554 pedestrian 0 - -
# 99 561 cyclist 0 - -
# 99 570 cyclist 0 - -
# 99 572 vehicle 0 - -
# 99 573 cyclist 0 - -
# 99 574 pedestrian 0 - -
# 99 582 cyclist 0 - -
# 99 584 pedestrian 0 - -
# 99 591 pedestrian 0 - -
# 99 592 cyclist 0 - -
# 99 593 pedestrian 0 - -
# 99 594 pedestrian 1 - -
# 99 595 pedestrian 0 - -
# 99 596 pedestrian 0 - -
# 99 597 pedestrian 0 - -
# 100 493 pedestrian 0 - -
# 100 547 pedestrian 0 - -
# 100 554 pedestrian 0 - -
# 100 561 cyclist 0 - -
# 100 570 cyclist 0 - -
# 100 572 vehicle 0 - -
# 100 573 cyclist 0 - -
# 100 574 pedestrian 0 - -
# 100 582 cyclist 0 - -
# 100 584 pedestrian 0 - -
# 100 591 pedestrian 0 - -
# 100 592 cyclist 0 - -
# 100 593 pedestrian 0 - -
# 100 594 pedestrian 0 - -
# 100 595 pedestrian 1 - -
# 100 596 pedestrian 0 - -
# 100 597 pedestrian 0 - -
# 100 598 pedestrian 0 - -
# 100 599 pedestrian 0 - -
# 100 600 cyclist 0 - -
# 101 493 pedestrian 0 - -
# 101 547 pedestrian 0 - -
# 101 554 pedestrian 0 - -
# 101 561 cyclist 0 - -
# 101 570 cyclist 0 - -
# 101 572 vehicle 0 - -
# 101 573 cyclist 0 - -
# 101 574 pedestrian 0 - -
# 101 582 cyclist 0 - -
# 101 584 pedestrian 0 - -
# 101 591 pedestrian 0 - -
# 101 592 cyclist 0 - -
# 101 593 pedestrian 0 - -
# 101 594 pedestrian 0 - -
# 101 596 pedestrian 0 - -
# 101 597 pedestrian 0 - -
# 101 598 pedestrian 0 - -
# 101 599 pedestrian 0 - -
# 101 600 vehicle 0 - -
# 102 493 pedestrian 0 - -
# 102 547 pedestrian 0 - -
# 102 554 pedestrian 0 - -
# 102 561 cyclist 0 - -
# 102 570 cyclist 0 - -
# 102 572 vehicle 0 - -
# 102 573 cyclist 0 - -
# 102 574 pedestrian 0 - -
# 102 582 cyclist 0 - -
# 102 584 pedestrian 0 - -
# 102 591 pedestrian 0 - -
# 102 592 cyclist 0 - -
# 102 593 pedestrian 0 - -
# 102 594 pedestrian 0 - -
# 102 596 pedestrian 0 - -
# 102 597 pedestrian 0 - -
# 102 598 pedestrian 0 - -
# 102 599 pedestrian 0 - -
# 102 600 vehicle 0 - -
# 103 493 pedestrian 0 - -
# 103 547 pedestrian 0 - -
# 103 554 pedestrian 0 - -
# 103 561 cyclist 0 - -
# 103 570 cyclist 0 - -
# 103 572 vehicle 0 - -
# 103 573 cyclist 0 - -
# 103 574 pedestrian 0 - -
# 103 582 cyclist 0 - -
# 103 584 pedestrian 0 - -
# 103 591 pedestrian 0 - -
# 103 592 cyclist 0 - -
# 103 593 pedestrian 0 - -
# 103 594 pedestrian 0 - -
# 103 596 pedestrian 0 - -
# 103 597 pedestrian 0 - -
# 103 598 pedestrian 0 - -
# 103 599 pedestrian 0 - -
# 103 600 vehicle 0 - -
# 104 493 pedestrian 0 - -
# 104 547 pedestrian 0 - -
# 104 554 pedestrian 0 - -
# 104 561 cyclist 0 - -
# 104 570 cyclist 0 - -
# 104 572 vehicle 0 - -
# 104 573 cyclist 0 - -
# 104 574 pedestrian 0 - -
# 104 582 cyclist 0 - -
# 104 584 pedestrian 0 - -
# 104 591 pedestrian 0 - -
# 104 592 cyclist 0 - -
# 104 593 pedestrian 0 - -
# 104 594 pedestrian 0 - -
# 104 596 pedestrian 0 - -
# 104 597 pedestrian 0 - -
# 104 598 pedestrian 0 - -
# 104 599 pedestrian 0 - -
# 104 600 vehicle 0 - -
# 105 493 pedestrian 0 - -
# 105 547 pedestrian 0 - -
# 105 554 pedestrian 0 - -
# 105 561 cyclist 0 - -
# 105 570 cyclist 0 - -
# 105 572 vehicle 0 - -
# 105 573 cyclist 0 - -
# 105 574 pedestrian 0 - -
# 105 582 cyclist 0 - -
# 105 584 pedestrian 0 - -
# 105 591 pedestrian 0 - -
# 105 592 cyclist 0 - -
# 105 593 pedestrian 0 - -
# 105 594 pedestrian 0 - -
# 105 596 pedestrian 0 - -
# 105 597 pedestrian 0 - -
# 105 598 pedestrian 0 - -
# 105 599 pedestrian 0 - -
# 105 600 vehicle 0 - -
# 106 493 pedestrian 0 - -
# 106 547 pedestrian 0 - -
# 106 554 pedestrian 0 - -
# 106 561 cyclist 0 - -
# 106 570 vehicle 0 - -
# 106 572 vehicle 0 - -
# 106 573 cyclist 0 - -
# 106 574 pedestrian 0 - -
# 106 582 cyclist 0 - -
# 106 584 pedestrian 0 - -
# 106 591 pedestrian 0 - -
# 106 592 cyclist 0 - -
# 106 593 pedestrian 0 - -
# 106 594 pedestrian 0 - -
# 106 596 pedestrian 0 - -
# 106 597 pedestrian 1 - -
# 106 598 pedestrian 0 - -
# 106 599 pedestrian 1 - -
# 106 600 cyclist 0 - -
# 107 493 pedestrian 0 - -
# 107 547 pedestrian 0 - -
# 107 554 pedestrian 0 - -
# 107 561 cyclist 0 - -
# 107 570 vehicle 0 - -
# 107 572 vehicle 0 - -
# 107 573 cyclist 0 - -
# 107 574 cyclist 0 - -
# 107 582 cyclist 0 - -
# 107 584 pedestrian 0 - -
# 107 591 pedestrian 0 - -
# 107 592 cyclist 0 - -
# 107 593 pedestrian 0 - -
# 107 594 pedestrian 0 - -
# 107 596 pedestrian 0 - -
# 107 598 pedestrian 0 - -
# 107 600 cyclist 0 - -
# 108 493 pedestrian 0 - -
# 108 547 pedestrian 0 - -
# 108 554 pedestrian 0 - -
# 108 561 cyclist 0 - -
# 108 570 vehicle 0 - -
# 108 572 vehicle 0 - -
# 108 573 cyclist 0 - -
# 108 574 cyclist 0 - -
# 108 582 cyclist 0 - -
# 108 584 pedestrian 0 - -
# 108 591 pedestrian 0 - -
# 108 592 cyclist 0 - -
# 108 593 pedestrian 0 - -
# 108 594 pedestrian 0 - -
# 108 596 pedestrian 0 - -
# 108 598 pedestrian 0 - -
# 108 600 cyclist 0 - -
# 109 493 pedestrian 0 - -
# 109 547 pedestrian 0 - -
# 109 554 pedestrian 0 - -
# 109 561 cyclist 0 - -
# 109 570 cyclist 0 - -
# 109 572 vehicle 0 - -
# 109 573 cyclist 0 - -
# 109 574 cyclist 0 - -
# 109 582 cyclist 0 - -
# 109 584 pedestrian 0 - -
# 109 591 pedestrian 0 - -
# 109 592 cyclist 0 - -
# 109 593 pedestrian 0 - -
# 109 594 pedestrian 0 - -
# 109 596 pedestrian 0 - -
# 109 598 pedestrian 1 - -
# 109 600 cyclist 0 - -
# 109 601 pedestrian 0 - -
# 109 602 pedestrian 0 - -
# 110 493 pedestrian 0 - -
# 110 547 pedestrian 0 - -
# 110 554 pedestrian 0 - -
# 110 561 cyclist 0 - -
# 110 570 cyclist 0 - -
# 110 572 vehicle 0 - -
# 110 573 cyclist 0 - -
# 110 574 cyclist 0 - -
# 110 582 cyclist 0 - -
# 110 584 pedestrian 0 - -
# 110 591 pedestrian 0 - -
# 110 592 pedestrian 0 - -
# 110 593 pedestrian 0 - -
# 110 594 pedestrian 1 - -
# 110 596 pedestrian 0 - -
# 110 600 cyclist 0 - -
# 110 601 pedestrian 0 - -
# 110 602 pedestrian 0 - -
# 111 493 pedestrian 0 - -
# 111 547 pedestrian 0 - -
# 111 554 pedestrian 0 - -
# 111 561 cyclist 0 - -
# 111 570 cyclist 0 - -
# 111 572 vehicle 0 - -
# 111 573 cyclist 0 - -
# 111 574 cyclist 0 - -
# 111 582 cyclist 0 - -
# 111 584 pedestrian 0 - -
# 111 591 pedestrian 0 - -
# 111 592 pedestrian 0 - -
# 111 593 pedestrian 0 - -
# 111 596 pedestrian 0 - -
# 111 600 cyclist 0 - -
# 111 601 pedestrian 0 - -
# 111 602 pedestrian 0 - -
# 111 603 pedestrian 0 - -
# 111 604 pedestrian 0 - -
# 112 493 pedestrian 0 - -
# 112 547 pedestrian 0 - -
# 112 554 pedestrian 0 - -
# 112 561 cyclist 0 - -
# 112 570 cyclist 0 - -
# 112 572 vehicle 0 - -
# 112 573 cyclist 0 - -
# 112 574 cyclist 0 - -
# 112 582 cyclist 0 - -
# 112 584 pedestrian 0 - -
# 112 591 pedestrian 0 - -
# 112 592 pedestrian 0 - -
# 112 593 pedestrian 0 - -
# 112 596 pedestrian 0 - -
# 112 600 cyclist 0 - -
# 112 601 pedestrian 0 - -
# 112 602 pedestrian 0 - -
# 112 603 pedestrian 0 - -
# 112 604 pedestrian 0 - -
# 113 493 pedestrian 0 - -
# 113 547 pedestrian 0 - -
# 113 554 pedestrian 0 - -
# 113 561 cyclist 0 - -
# 113 570 cyclist 0 - -
# 113 572 vehicle 0 - -
# 113 573 cyclist 0 - -
# 113 574 pedestrian 0 - -
# 113 582 cyclist 0 - -
# 113 584 pedestrian 0 - -
# 113 591 pedestrian 0 - -
# 113 592 cyclist 0 - -
# 113 593 pedestrian 0 - -
# 113 596 pedestrian 0 - -
# 113 600 cyclist 1 - -
# 113 601 pedestrian 0 - -
# 113 602 pedestrian 0 - -
# 113 603 pedestrian 0 - -
# 113 604 pedestrian 0 - -
# 114 493 pedestrian 0 - -
# 114 547 pedestrian 0 - -
# 114 554 pedestrian 0 - -
# 114 561 cyclist 0 - -
# 114 570 cyclist 0 - -
# 114 572 vehicle 0 - -
# 114 573 cyclist 0 - -
# 114 574 cyclist 0 - -
# 114 582 cyclist 0 - -
# 114 584 pedestrian 0 - -
# 114 591 pedestrian 0 - -
# 114 592 pedestrian 0 - -
# 114 593 pedestrian 0 - -
# 114 596 pedestrian 0 - -
# 114 601 pedestrian 0 - -
# 114 602 pedestrian 0 - -
# 114 603 pedestrian 0 - -
# 114 604 pedestrian 0 - -
# 115 493 pedestrian 0 - -
# 115 547 pedestrian 0 - -
# 115 554 pedestrian 0 - -
# 115 561 cyclist 0 - -
# 115 570 cyclist 0 - -
# 115 572 vehicle 0 - -
# 115 573 cyclist 0 - -
# 115 574 cyclist 0 - -
# 115 582 cyclist 0 - -
# 115 584 pedestrian 0 - -
# 115 591 pedestrian 0 - -
# 115 592 pedestrian 0 - -
# 115 593 pedestrian 0 - -
# 115 596 pedestrian 0 - -
# 115 601 pedestrian 0 - -
# 115 602 pedestrian 0 - -
# 115 603 pedestrian 0 - -
# 115 604 pedestrian 0 - -
# 115 605 pedestrian 0 - -
# 116 493 pedestrian 0 - -
# 116 547 pedestrian 0 - -
# 116 554 pedestrian 0 - -
# 116 561 cyclist 0 - -
# 116 570 cyclist 0 - -
# 116 572 vehicle 0 - -
# 116 573 cyclist 0 - -
# 116 574 pedestrian 0 - -
# 116 582 cyclist 0 - -
# 116 584 pedestrian 0 - -
# 116 591 pedestrian 0 - -
# 116 592 cyclist 0 - -
# 116 593 pedestrian 0 - -
# 116 596 pedestrian 0 - -
# 116 601 pedestrian 0 - -
# 116 602 pedestrian 0 - -
# 116 603 pedestrian 1 - -
# 116 604 pedestrian 0 - -
# 116 605 pedestrian 0 - -
# 117 493 pedestrian 0 - -
# 117 547 pedestrian 0 - -
# 117 554 pedestrian 0 - -
# 117 561 cyclist 0 - -
# 117 570 cyclist 0 - -
# 117 572 vehicle 0 - -
# 117 573 cyclist 0 - -
# 117 574 pedestrian 0 - -
# 117 582 cyclist 0 - -
# 117 584 pedestrian 0 - -
# 117 591 pedestrian 0 - -
# 117 592 cyclist 0 - -
# 117 593 pedestrian 0 - -
# 117 596 pedestrian 0 - -
# 117 601 pedestrian 0 - -
# 117 602 pedestrian 0 - -
# 117 604 pedestrian 0 - -
# 117 605 pedestrian 0 - -
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [50], in <cell line: 1>()
# ----> 1 for i, images in enumerate(detector):
#       2     detector.detect_object_2D(images[0], frame_num=i, save_images=False)
#
# Input In [48], in ObjectDetector.__iter__(self)
#      23 for file_1, file_2 in zip_longest(self.files_1, self.files_2, fillvalue=None):
#      24     img_1 = cv2.imread(str(file_1))
# ---> 25     img_2 = cv2.imread(str(file_2))
#      26     yield (img_1, img_2)
#
# File c:\Python3\lib\site-packages\ultralytics\utils\patches.py:26, in imread(filename, flags)
#      15 def imread(filename: str, flags: int = cv2.IMREAD_COLOR):
#      16     """
#      17     Read an image from a file.
#      18
#    (...)
#      24         (np.ndarray): The read image.
#      25     """
# ---> 26     return cv2.imdecode(np.fromfile(filename, np.uint8), flags)
#
# KeyboardInterrupt:

# %%
detector.create_video(images_dir="./outputs", output_video_path="./output_video.mp4", fps=30)
# Out:
# Video creado exitosamente: ./output_video.mp4

# %%
while True:
    # 1. New frame (2)
    frame = get_next_frame()
    
    # 2. Yolo detection in 2 stereo images
    detections_2d = yolo_model.detect(frame)
    
    # 3.3D reconstruction (center x,y in 2 stereo images)
    detections_3d = []
    for bbox in detections_2d:

        Z = disparity_to_depth(disparity_map[bbox_center_y1, bbox_center_x1, bbox_center_y2, bbox_center_x2 ])

        X = (bbox_center_x - cx) * Z / fx
        Y = (bbox_center_y - cy) * Z / fy
        detections_3d.append(point_3d)
    
    # 4 detect oclusion (if oclusion kalman, if not linear interpolation of line tracker.)
    
        # 4A. UPDATE tracker
        active_tracks = KALMAN.tracker.update(detections_3d)
        
        # 5A. visualize results:
        for track_id, track in active_tracks.items():
            position = track['kalman'].state[:3]  # Posición filtrada
            velocity = track['kalman'].state[3:]  # Velocidad estimada
            draw_track(frame, position, track_id)
            
        #4A linear interpolation
